# %%
# %matplotlib notebook

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
import csv
from sklearn import svm
import sklearn.feature_extraction.text
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import itertools
from sklearn import preprocessing
import re
import string
import graphviz
np.random.seed(2)

plt.ioff()
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Download data from https://www.kaggle.com/crowdflower/twitter-airline-sentiment

# %%
data_frame = pd.read_csv('data/Tweets.csv')

# %%
print("{} Tweets in dataset".format(len(data_frame)))
data_frame.head()
# Out:
# 14640 Tweets in dataset
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
tweets_text = data_frame['text']

# %%
print("Tweet: {}".format(tweets_text[16]))
# Out:
# Tweet: @VirginAmerica So excited for my first cross country flight LAX to MCO I've heard nothing but great things about Virgin America. #29DaysToGo

# %%
tweets_text_clean = [u' starttoken ' + unicode(t, 'utf-8') + u' endtoken ' for t in tweets_text]

# %%
print("Tweet: {}".format(tweets_text_clean[16]))
# Out:
# Tweet:  starttoken @VirginAmerica So excited for my first cross country flight LAX to MCO I've heard nothing but great things about Virgin America. #29DaysToGo endtoken

# %%
def get_gram_dictionary_probabilities(ngram_size):
    vect = sklearn.feature_extraction.text.CountVectorizer(ngram_range=(ngram_size, ngram_size), 
                                                           strip_accents=False,
                                                          )
    vect.fit(tweets_text_clean)
    vocab = vect.get_feature_names()
    bow = vect.transform(tweets_text_clean)
    dist = np.sum(bow, axis=0)
    dist = [dist[0,di] for di in range(len(vocab))]
    ngram_freq = {}

    # Count ngram frequencies
    for tag, count in zip(vocab, dist):
        ngram_freq[tag] = count

    # create mapping from prior words -> potential words list
    preceding_gram_to_options_with_counts = {}
    for token in ngram_freq.keys():
        grams = token.split(' ')
        preceding = u' '.join(token.split(u' ')[:-1])
        next_token = token.split(u' ')[-1]
        if next_token != 'starttoken':
            options_so_far = preceding_gram_to_options_with_counts.get(preceding, [])
            options_so_far.append((next_token, ngram_freq[token]))
            preceding_gram_to_options_with_counts[preceding] = options_so_far

    preceding_gram_to_options_with_counts_normalized = {}
    for preciding_gram, options in preceding_gram_to_options_with_counts.iteritems():
        normalized_options = []
        total_counts = float(np.sum([count for option, count in options]))
        normalized_options = [(option, count/total_counts) for option, count in options]
        preceding_gram_to_options_with_counts_normalized[preciding_gram] = normalized_options
        
    return preceding_gram_to_options_with_counts_normalized

gram_5_dict_prob = get_gram_dictionary_probabilities(5)
gram_4_dict_prob = get_gram_dictionary_probabilities(4)
gram_3_dict_prob = get_gram_dictionary_probabilities(3)
gram_2_dict_prob = get_gram_dictionary_probabilities(2)
gram_1_dict_prob = get_gram_dictionary_probabilities(1)

gram_dict_probs = [(gram_5_dict_prob, 5), (gram_4_dict_prob, 4), (gram_3_dict_prob, 3), (gram_2_dict_prob, 2), (gram_1_dict_prob, 1)]

# %%
gram_3_dict_prob
# Out:
# {u'helpful we': [(u'can', 1.0)],
#  u'shows delayed': [(u'trying', 0.5), (u'it', 0.5)],
#  u'americanair hopefully': [(u'you', 0.66666666666666663),
#   (u'it', 0.33333333333333331)],
#  u'in route': [(u'now', 1.0)],
#  u'completely unanticipated': [(u'endtoken', 1.0)],
#  u'las she': [(u'also', 1.0)],
#  u'hoom me': [(u'up', 1.0)],
#  u'your whole': [(u'handling', 0.5), (u'organization', 0.5)],
#  u'as offer': [(u'hotel', 1.0)],
#  u'text message': [(u'received', 1.0)],
#  u'denver just': [(u'got', 1.0)],
#  u'thing we': [(u'noticed', 1.0)],
#  u'to del': [(u'preferably', 1.0)],
#  u'changes in': [(u'30', 0.33333333333333331),
#   (u'the', 0.33333333333333331),
#   (u'atlanta', 0.33333333333333331)],
#  u'or just': [(u'stupid', 0.1111111111111111),
#   (u'endtoken', 0.1111111111111111),
#   (u'making', 0.1111111111111111),
#   (u'days', 0.1111111111111111),
#   (u'american', 0.1111111111111111),
#   (u'showing', 0.1111111111111111),
#   (u'when', 0.1111111111111111),
#   (u'northeast', 0.1111111111111111),
#   (u'money', 0.1111111111111111)],
#  u'rude show': [(u'of', 1.0)],
#  u'to prevent': [(u'dvt', 0.20000000000000001),
#   (u'the', 0.20000000000000001),
#   (u'me', 0.20000000000000001),
#   (u'or', 0.20000000000000001),
#   (u'this', 0.20000000000000001)],
#  u'trips get': [(u'me', 1.0)],
#  u'kiosks were': [(u'broken', 1.0)],
#  u'haha that': [(u'will', 0.5), (u'fine', 0.5)],
#  u'from nzherald': [(u'http', 1.0)],
#  u'traveling lot': [(u'as', 1.0)],
#  u'dime to': [(u'enjoy', 1.0)],
#  u'our benefits': [(u'aren', 1.0)],
#  u'still get': [(u'notifications', 0.33333333333333331),
#   (u'credit', 0.33333333333333331),
#   (u'the', 0.33333333333333331)],
#  u'called for': [(u'preboarding', 0.20000000000000001),
#   (u'days', 0.40000000000000002),
#   (u'hours', 0.20000000000000001),
#   (u'baggage', 0.20000000000000001)],
#  u'truly appreciate': [(u'the', 1.0)],
#  u'the mojave': [(u'desert', 1.0)],
#  u'makes timieyancey': [(u'very', 1.0)],
#  u'will make': [(u'complaint', 0.055555555555555552),
#   (u'the', 0.1111111111111111),
#   (u'everything', 0.055555555555555552),
#   (u'up', 0.055555555555555552),
#   (u'this', 0.1111111111111111),
#   (u'sure', 0.16666666666666666),
#   (u'my', 0.1111111111111111),
#   (u'good', 0.055555555555555552),
#   (u'fun', 0.055555555555555552),
#   (u'it', 0.22222222222222221)],
#  u'aa 2258': [(u'monday', 0.5), (u'why', 0.5)],
#  u'flighting out': [(u'of', 1.0)],
#  u'update ur': [(u'systems', 1.0)],
#  u'abcnetwork oscars': [(u'coverage', 1.0)],
#  u'expect the': [(u'unexpected', 0.5), (u'formal', 0.5)],
#  u'the real': [(u'thing', 0.14285714285714285),
#   (u'reason', 0.14285714285714285),
#   (u'deal', 0.14285714285714285),
#   (u'is', 0.14285714285714285),
#   (u'mvp', 0.42857142857142855)],
#  u'injured gate': [(u'agent', 1.0)],
#  u'details apology': [(u'info', 1.0)],
#  u'of hand': [(u'called', 1.0)],
#  u'starttoken real': [(u'rt', 1.0)],
#  u'any ways': [(u'to', 1.0)],
#  u'marsha at': [(u'myrtle', 1.0)],
#  u'stop will': [(u'be', 1.0)],
#  u'your website': [(u'with', 0.016393442622950821),
#   (u'just', 0.016393442622950821),
#   (u'has', 0.016393442622950821),
#   (u'policy', 0.016393442622950821),
#   (u'promises', 0.016393442622950821),
#   (u'ever', 0.016393442622950821),
#   (u'downnnnn', 0.016393442622950821),
#   (u'traveling', 0.016393442622950821),
#   (u'flight', 0.032786885245901641),
#   (u'down', 0.032786885245901641),
#   (u'to', 0.016393442622950821),
#   (u'and', 0.049180327868852458),
#   (u'after', 0.016393442622950821),
#   (u'soreback', 0.016393442622950821),
#   (u'from', 0.016393442622950821),
#   (u'isn', 0.032786885245901641),
#   (u'many', 0.016393442622950821),
#   (u'amp', 0.032786885245901641),
#   (u'can', 0.016393442622950821),
#   (u'asap', 0.016393442622950821),
#   (u'thanks', 0.016393442622950821),
#   (u'seems', 0.032786885245901641),
#   (u'btw', 0.016393442622950821),
#   (u'sucks', 0.016393442622950821),
#   (u'it', 0.049180327868852458),
#   (u'is', 0.14754098360655737),
#   (u'was', 0.016393442622950821),
#   (u'noloveforsurfers', 0.016393442622950821),
#   (u'unacceptable', 0.016393442622950821),
#   (u'endtoken', 0.13114754098360656),
#   (u'worked', 0.016393442622950821),
#   (u'won', 0.032786885245901641),
#   (u'until', 0.016393442622950821),
#   (u'deserves', 0.016393442622950821),
#   (u'says', 0.032786885245901641)],
#  u'any notification': [(u'that', 1.0)],
#  u'really true': [(u'blue', 1.0)],
#  u'on 919': [(u'endtoken', 1.0)],
#  u'miss options': [(u'anyway', 1.0)],
#  u'wernicke beat': [(u'in', 1.0)],
#  u'uses at': [(u'mco', 1.0)],
#  u'completely displeased': [(u'with', 1.0)],
#  u'outlets but': [(u'our', 1.0)],
#  u'had better': [(u'mobile', 0.5), (u'be', 0.5)],
#  u'they told': [(u'me', 0.40000000000000002),
#   (u'her', 0.10000000000000001),
#   (u'to', 0.10000000000000001),
#   (u'him', 0.10000000000000001),
#   (u'us', 0.29999999999999999)],
#  u'destination flight': [(u'3618', 1.0)],
#  u'now when': [(u'will', 0.25),
#   (u'can', 0.25),
#   (u'the', 0.25),
#   (u'call', 0.25)],
#  u'bc weather': [(u'southwestair', 1.0)],
#  u'by announcing': [(u'arrival', 1.0)],
#  u'for quick': [(u'reply', 0.16666666666666666),
#   (u'response', 0.16666666666666666),
#   (u'decision', 0.16666666666666666),
#   (u'dm', 0.33333333333333331),
#   (u'responses', 0.16666666666666666)],
#  u'white listed': [(u'so', 1.0)],
#  u'cool never': [(u'been', 1.0)],
#  u'split myself': [(u'and', 1.0)],
#  u'probably didn': [(u'even', 1.0)],
#  u'food available': [(u'even', 1.0)],
#  u'our miles': [(u'from', 1.0)],
#  u'usairways so': [(u'when', 0.028571428571428571),
#   (u'we', 0.028571428571428571),
#   (u'was', 0.028571428571428571),
#   (u'you', 0.17142857142857143),
#   (u'how', 0.028571428571428571),
#   (u'guess', 0.028571428571428571),
#   (u'would', 0.028571428571428571),
#   (u'the', 0.028571428571428571),
#   (u'ask', 0.028571428571428571),
#   (u'apparently', 0.028571428571428571),
#   (u'frustrating', 0.028571428571428571),
#   (u'far', 0.11428571428571428),
#   (u'can', 0.028571428571428571),
#   (u'mad', 0.028571428571428571),
#   (u'my', 0.028571428571428571),
#   (u'what', 0.028571428571428571),
#   (u'basically', 0.028571428571428571),
#   (u'upset', 0.028571428571428571),
#   (u'who', 0.028571428571428571),
#   (u'am', 0.028571428571428571),
#   (u'any', 0.028571428571428571),
#   (u'no', 0.028571428571428571),
#   (u'she', 0.028571428571428571),
#   (u'still', 0.028571428571428571),
#   (u'it', 0.028571428571428571),
#   (u'get', 0.028571428571428571),
#   (u'disappointed', 0.028571428571428571)],
#  u'yow but': [(u'now', 1.0)],
#  u'flight ridiculous': [(u'endtoken', 0.5), (u'phlairport', 0.5)],
#  u'in history': [(u'endtoken', 0.5), (u'll', 0.5)],
#  u'cool the': [(u'plane', 1.0)],
#  u'now why': [(u'switched', 1.0)],
#  u'jetblue gr8': [(u'mint', 1.0)],
#  u'and alerts': [(u'have', 1.0)],
#  u'cancun undefined': [(u'error', 1.0)],
#  u'us hr': [(u'layover', 1.0)],
#  u'died during': [(u'the', 1.0)],
#  u'one usairwaysfail': [(u'endtoken', 1.0)],
#  u'to fear': [(u'losing', 1.0)],
#  u'different sw': [(u'should', 1.0)],
#  u'australia thanks': [(u'endtoken', 1.0)],
#  u'main 800': [(u'number', 1.0)],
#  u'mco flight': [(u'and', 1.0)],
#  u'no fresh': [(u'food', 1.0)],
#  u'fucking cot': [(u'what', 1.0)],
#  u'hidden in': [(u'the', 1.0)],
#  u'your black': [(u'history', 1.0)],
#  u'this little': [(u'bitty', 1.0)],
#  u'days 20': [(u'calls', 1.0)],
#  u'perfect probably': [(u'need', 1.0)],
#  u'flightlation alaskaair': [(u'and', 1.0)],
#  u'slept in': [(u'the', 0.40000000000000002),
#   (u'an', 0.40000000000000002),
#   (u'endtoken', 0.20000000000000001)],
#  u'had flashlight': [(u'dropped', 1.0)],
#  u'mc caren': [(u'to', 1.0)],
#  u'southwestair hello': [(u'swa', 0.14285714285714285),
#   (u'remaining', 0.14285714285714285),
#   (u'are', 0.14285714285714285),
#   (u'southwestair', 0.14285714285714285),
#   (u'my', 0.14285714285714285),
#   (u'was', 0.14285714285714285),
#   (u'been', 0.14285714285714285)],
#  u'employees treated': [(u'us', 1.0)],
#  u'boards and': [(u'once', 1.0)],
#  u'miles needed': [(u'was', 1.0)],
#  u'4me around': [(u'midnite', 1.0)],
#  u'10 any': [(u'advice', 1.0)],
#  u'nailed the': [(u'landing', 1.0)],
#  u'the automatic': [(u'phone', 1.0)],
#  u'could download': [(u'movie', 1.0)],
#  u'itinerary changes': [(u'and', 1.0)],
#  u'750 for': [(u'539', 1.0)],
#  u'is rip': [(u'off', 1.0)],
#  u'startups tech': [(u'endtoken', 1.0)],
#  u'american company': [(u'would', 1.0)],
#  u'hour we': [(u'finally', 1.0)],
#  u'bags like': [(u'alaskaair', 0.5), (u'you', 0.5)],
#  u'conversation they': [(u'seem', 1.0)],
#  u'up until': [(u'12', 0.5), (u'tomorrow', 0.5)],
#  u'wasn forced': [(u'to', 1.0)],
#  u'miles ticket': [(u'after', 0.5), (u'cutting', 0.5)],
#  u'on phone': [(u'this', 0.030303030303030304),
#   (u'with', 0.12121212121212122),
#   (u'help', 0.030303030303030304),
#   (u'flt', 0.030303030303030304),
#   (u'would', 0.030303030303030304),
#   (u'not', 0.030303030303030304),
#   (u'amp', 0.060606060606060608),
#   (u'for', 0.030303030303030304),
#   (u'new', 0.060606060606060608),
#   (u'unacceptable', 0.030303030303030304),
#   (u'hours', 0.030303030303030304),
#   (u'wtf', 0.030303030303030304),
#   (u'iwas', 0.030303030303030304),
#   (u'im', 0.030303030303030304),
#   (u'is', 0.030303030303030304),
#   (u'hold', 0.030303030303030304),
#   (u'endtoken', 0.090909090909090912),
#   (u'still', 0.030303030303030304),
#   (u'though', 0.030303030303030304),
#   (u'long', 0.030303030303030304),
#   (u'to', 0.18181818181818182)],
#  u'actually answer': [(u'the', 1.0)],
#  u'media person': [(u'endtoken', 1.0)],
#  u'no response': [(u'little', 0.027027027027027029),
#   (u'yet', 0.027027027027027029),
#   (u'obviously', 0.027027027027027029),
#   (u'was', 0.027027027027027029),
#   (u'and', 0.027027027027027029),
#   (u'disappointed', 0.027027027027027029),
#   (u'help', 0.027027027027027029),
#   (u'on', 0.054054054054054057),
#   (u'need', 0.054054054054054057),
#   (u'have', 0.027027027027027029),
#   (u'to', 0.16216216216216217),
#   (u'endtoken', 0.16216216216216217),
#   (u'in', 0.027027027027027029),
#   (u'from', 0.081081081081081086),
#   (u'weeks', 0.027027027027027029),
#   (u'hours', 0.027027027027027029),
#   (u'what', 0.027027027027027029),
#   (u'please', 0.027027027027027029),
#   (u'lousy', 0.027027027027027029),
#   (u'so', 0.027027027027027029),
#   (u'back', 0.054054054054054057),
#   (u'is', 0.027027027027027029)],
#  u'tix month': [(u'ago', 1.0)],
#  u'they don': [(u'really', 0.050000000000000003),
#   (u'even', 0.14999999999999999),
#   (u'want', 0.050000000000000003),
#   (u'endtoken', 0.050000000000000003),
#   (u'scan', 0.050000000000000003),
#   (u'recline', 0.050000000000000003),
#   (u'care', 0.10000000000000001),
#   (u'hold', 0.050000000000000003),
#   (u'honor', 0.050000000000000003),
#   (u'follow', 0.050000000000000003),
#   (u'have', 0.10000000000000001),
#   (u'stand', 0.050000000000000003),
#   (u'answer', 0.050000000000000003),
#   (u'handle', 0.050000000000000003),
#   (u'check', 0.050000000000000003),
#   (u'cut', 0.050000000000000003)],
#  u'as tweet': [(u'one', 1.0)],
#  u'ball here': [(u'endtoken', 1.0)],
#  u'see grand': [(u'kids', 1.0)],
#  u'big or': [(u'small', 1.0)],
#  u'shitty fucking': [(u'information', 1.0)],
#  u'am domestic': [(u'flight', 1.0)],
#  u'guitars can': [(u'we', 1.0)],
#  u'night 1235': [(u'ord', 1.0)],
#  u'bags bag': [(u'fnd', 1.0)],
#  u'united haha': [(u'that', 0.5), (u'and', 0.5)],
#  u'we went': [(u'thru', 0.5), (u'through', 0.5)],
#  u'cmh ord': [(u'option', 1.0)],
#  u'the recognition': [(u'she', 1.0)],
#  u'portcolumbuscmh today': [(u'finally', 1.0)],
#  u'spiritairlines sign': [(u'me', 1.0)],
#  u'about not': [(u'serving', 0.5), (u'being', 0.5)],
#  u'about now': [(u'getting', 1.0)],
#  u'cases can': [(u'you', 1.0)],
#  u'assignment mins': [(u'before', 1.0)],
#  u'find these': [(u'bags', 1.0)],
#  u'q3 2014': [(u'also', 1.0)],
#  u'mine terribly': [(u'for', 1.0)],
#  u'30 credit': [(u'as', 1.0)],
#  u'mci to': [(u'clt', 0.33333333333333331),
#   (u'endtoken', 0.33333333333333331),
#   (u'del', 0.33333333333333331)],
#  u'co hfof33iyhi': [(u'endtoken', 1.0)],
#  u'told got': [(u'put', 1.0)],
#  u'keep holding': [(u'endtoken', 1.0)],
#  u'and email': [(u'have', 0.25),
#   (u'address', 0.25),
#   (u'and', 0.25),
#   (u'on', 0.25)],
#  u'the slog': [(u'from', 1.0)],
#  u'my problem': [(u'so', 0.16666666666666666),
#   (u'if', 0.16666666666666666),
#   (u'were', 0.16666666666666666),
#   (u'shannon', 0.16666666666666666),
#   (u'from', 0.16666666666666666),
#   (u'endtoken', 0.16666666666666666)],
#  u'way that': [(u'am', 0.25),
#   (u'can', 0.125),
#   (u'someone', 0.125),
#   (u'you', 0.25),
#   (u'we', 0.25)],
#  u'again valuable': [(u'time', 1.0)],
#  u'2464 cancelled': [(u'flightled', 1.0)],
#  u'the slow': [(u'wifi', 1.0)],
#  u'tix no': [(u'thx', 1.0)],
#  u'passengers now': [(u'that', 0.5), (u'request', 0.5)],
#  u'passengers not': [(u'send', 1.0)],
#  u'payment method': [(u'to', 1.0)],
#  u'strike three': [(u'you', 1.0)],
#  u'now cost': [(u'me', 1.0)],
#  u'line due': [(u'to', 1.0)],
#  u'feature for': [(u'country', 1.0)],
#  u'for glitchy': [(u'tracking', 1.0)],
#  u'agent all': [(u'taken', 1.0)],
#  u'worst airline': [(u'ever', 0.34693877551020408),
#   (u'lost', 0.020408163265306121),
#   (u'congrats', 0.020408163265306121),
#   (u'in', 0.18367346938775511),
#   (u'goingforgreatnessfail', 0.020408163265306121),
#   (u'experience', 0.020408163265306121),
#   (u'badservice', 0.020408163265306121),
#   (u'period', 0.020408163265306121),
#   (u'but', 0.020408163265306121),
#   (u'endtoken', 0.020408163265306121),
#   (u'to', 0.061224489795918366),
#   (u've', 0.061224489795918366),
#   (u'out', 0.020408163265306121),
#   (u'plane', 0.020408163265306121),
#   (u'13', 0.020408163265306121),
#   (u'wellplayed', 0.020408163265306121),
#   (u'you', 0.040816326530612242),
#   (u'beware', 0.020408163265306121),
#   (u'of', 0.020408163265306121),
#   (u'jetblue', 0.020408163265306121)],
#  u'count on': [(u'my', 1.0)],
#  u'class cockup': [(u'http', 1.0)],
#  u'thing http': [(u'co', 1.0)],
#  u'service displayed': [(u'over', 1.0)],
#  u'your experts': [(u'seen', 1.0)],
#  u'was uncompromising': [(u'we', 1.0)],
#  u'or flight': [(u'home', 1.0)],
#  u'have transportation': [(u'waiting', 1.0)],
#  u'worst http': [(u'co', 1.0)],
#  u'rebook and': [(u'now', 0.5), (u'cannot', 0.5)],
#  u'wut jetblue': [(u'our', 1.0)],
#  u'not notify': [(u'us', 1.0)],
#  u'problems doesn': [(u'anyone', 1.0)],
#  u'we pointed': [(u'it', 1.0)],
#  u'luck help': [(u'endtoken', 1.0)],
#  u'til he': [(u'needed', 1.0)],
#  u'it took': [(u'about', 0.16666666666666666),
#   (u'more', 0.16666666666666666),
#   (u'ages', 0.16666666666666666),
#   (u'the', 0.16666666666666666),
#   (u'over', 0.16666666666666666),
#   (u'them', 0.16666666666666666)],
#  u'count of': [(u'transfers', 1.0)],
#  u'flight 1373': [(u'for', 1.0)],
#  u'southwestair tmadcle': [(u'flying', 1.0)],
#  u'can call': [(u'will', 0.047619047619047616),
#   (u'need', 0.047619047619047616),
#   (u'endtoken', 0.095238095238095233),
#   (u'you', 0.047619047619047616),
#   (u'regarding', 0.047619047619047616),
#   (u'it', 0.047619047619047616),
#   (u'when', 0.047619047619047616),
#   (u'to', 0.33333333333333331),
#   (u'them', 0.047619047619047616),
#   (u'customer', 0.047619047619047616),
#   (u'because', 0.047619047619047616),
#   (u'me', 0.095238095238095233),
#   (u'right', 0.047619047619047616)],
#  u'740pm wheels': [(u'up', 1.0)],
#  u'tix we': [(u'are', 1.0)],
#  u'never disappoints': [(u'endtoken', 1.0)],
#  u'express checkin': [(u'weeks', 1.0)],
#  u'meeting at': [(u'work', 1.0)],
#  u'on advise': [(u'endtoken', 1.0)],
#  u'number from': [(u'delta', 1.0)],
#  u'useless air': [(u'staff', 1.0)],
#  u'by mistake': [(u'and', 1.0)],
#  u'today great': [(u'crew', 0.5), (u'way', 0.5)],
#  u'me still': [(u'haven', 1.0)],
#  u'crew can': [(u'fly', 1.0)],
#  u'lots to': [(u'do', 1.0)],
#  u'changing flight': [(u'to', 0.5), (u'please', 0.5)],
#  u'document keep': [(u'getting', 1.0)],
#  u'response and': [(u'no', 0.33333333333333331),
#   (u'apology', 0.33333333333333331),
#   (u'action', 0.33333333333333331)],
#  u'and pssgrs': [(u'stranded', 1.0)],
#  u'shift for': [(u'impending', 1.0)],
#  u'rough eta': [(u'would', 1.0)],
#  u'only reason': [(u've', 1.0)],
#  u'social listening': [(u'capabilities', 1.0)],
#  u'for us628': [(u'dfw', 1.0)],
#  u'to extreme': [(u'disorganization', 1.0)],
#  u'speed dial': [(u'endtoken', 1.0)],
#  u'southwestair cancelled': [(u'flighted', 0.090909090909090912),
#   (u'flights', 0.090909090909090912),
#   (u'flightled', 0.63636363636363635),
#   (u'flighting', 0.090909090909090912),
#   (u'flightling', 0.090909090909090912)],
#  u'be expecting': [(u'credit', 1.0)],
#  u'to sacramento': [(u'from', 1.0)],
#  u'text but': [(u'not', 1.0)],
#  u'relations or': [(u'refund', 1.0)],
#  u'office even': [(u'something', 1.0)],
#  u'not something': [(u'we', 0.33333333333333331),
#   (u'pretty', 0.33333333333333331),
#   (u'that', 0.33333333333333331)],
#  u'flightled just': [(u'as', 1.0)],
#  u'checking the': [(u'plane', 0.5), (u'extra', 0.5)],
#  u'spot amp': [(u'everyone', 1.0)],
#  u'girl raise': [(u'she', 1.0)],
#  u'iced coffee': [(u'endtoken', 1.0)],
#  u'communication amp': [(u'no', 1.0)],
#  u'united danahajek': [(u'united', 0.5), (u'she', 0.5)],
#  u'was reason': [(u'for', 0.5), (u'were', 0.5)],
#  u'site keeps': [(u'giving', 1.0)],
#  u'abroad badcustomerservice': [(u'fend4yourself', 1.0)],
#  u'follow you': [(u'one', 0.16666666666666666),
#   (u'back', 0.16666666666666666),
#   (u'endtoken', 0.16666666666666666),
#   (u'and', 0.33333333333333331),
#   (u'now', 0.16666666666666666)],
#  u'applying my': [(u'new', 1.0)],
#  u'chairs get': [(u'free', 1.0)],
#  u'poor experience': [(u'2day', 0.25),
#   (u'first', 0.25),
#   (u'into', 0.25),
#   (u'please', 0.25)],
#  u'1of flights': [(u'an', 1.0)],
#  u'can tell': [(u'customer', 0.058823529411764705),
#   (u'when', 0.058823529411764705),
#   (u'purchase', 0.058823529411764705),
#   (u'my', 0.11764705882352941),
#   (u'me', 0.41176470588235292),
#   (u'you', 0.17647058823529413),
#   (u'if', 0.058823529411764705),
#   (u'at', 0.058823529411764705)],
#  u'old child': [(u'fold', 0.33333333333333331),
#   (u'from', 0.33333333333333331),
#   (u'have', 0.33333333333333331)],
#  u'again until': [(u'1225', 1.0)],
#  u'after applying': [(u'my', 1.0)],
#  u'keep emily': [(u'at', 1.0)],
#  u'sunday just': [(u'few', 1.0)],
#  u'of fun': [(u'to', 1.0)],
#  u'ord and': [(u'is', 0.25),
#   (u'now', 0.25),
#   (u'clear', 0.25),
#   (u'miss', 0.25)],
#  u'baggage attendants': [(u'at', 1.0)],
#  u'question want': [(u'to', 1.0)],
#  u'expanded email': [(u'thank', 1.0)],
#  u'realtime appreciation': [(u'from', 1.0)],
#  u'door more': [(u'strange', 1.0)],
#  u'became best': [(u'friends', 1.0)],
#  u'have bags': [(u'will', 0.33333333333333331),
#   (u'on', 0.33333333333333331),
#   (u'by', 0.33333333333333331)],
#  u'on super': [(u'large', 1.0)],
#  u'2chng even': [(u'though', 1.0)],
#  u'huston tonight': [(u'and', 1.0)],
#  u'january 26th': [(u'2015', 1.0)],
#  u'destination airport': [(u'to', 1.0)],
#  u'take jetblue': [(u'because', 0.5), (u'to', 0.5)],
#  u'delta next': [(u'time', 1.0)],
#  u'time before': [(u'anyone', 0.5), (u'recommend', 0.5)],
#  u'h2o and': [(u'received', 1.0)],
#  u'just remember': [(u'that', 1.0)],
#  u'just 17': [(u'days', 1.0)],
#  u'jetblue flight': [(u'152', 0.019607843137254902),
#   (u'delayed', 0.039215686274509803),
#   (u'booked', 0.019607843137254902),
#   (u'691', 0.019607843137254902),
#   (u'for', 0.019607843137254902),
#   (u'918', 0.019607843137254902),
#   (u'894', 0.019607843137254902),
#   (u'in', 0.039215686274509803),
#   (u'is', 0.039215686274509803),
#   (u'to', 0.019607843137254902),
#   (u'672', 0.019607843137254902),
#   (u'1025', 0.019607843137254902),
#   (u'1183', 0.019607843137254902),
#   (u'2008', 0.019607843137254902),
#   (u'69', 0.019607843137254902),
#   (u'462', 0.019607843137254902),
#   (u'1533', 0.019607843137254902),
#   (u'attendant', 0.039215686274509803),
#   (u'136', 0.039215686274509803),
#   (u'348', 0.019607843137254902),
#   (u'99', 0.019607843137254902),
#   (u'98', 0.019607843137254902),
#   (u'123', 0.019607843137254902),
#   (u'790', 0.019607843137254902),
#   (u'705', 0.019607843137254902),
#   (u'1951', 0.019607843137254902),
#   (u'2302', 0.019607843137254902),
#   (u'want', 0.019607843137254902),
#   (u'booking', 0.019607843137254902),
#   (u'117', 0.019607843137254902),
#   (u'2202', 0.019607843137254902),
#   (u'1447', 0.019607843137254902),
#   (u'1133', 0.019607843137254902),
#   (u'from', 0.058823529411764705),
#   (u'1041', 0.019607843137254902),
#   (u'226', 0.019607843137254902),
#   (u'16', 0.019607843137254902),
#   (u'577', 0.019607843137254902),
#   (u'delay', 0.019607843137254902),
#   (u'flight', 0.019607843137254902),
#   (u'1562', 0.039215686274509803),
#   (u'was', 0.039215686274509803)],
#  u'hubby got': [(u'100', 1.0)],
#  u'flightation you': [(u'can', 1.0)],
#  u'opened rude': [(u'attendants', 1.0)],
#  u'on 915': [(u'endtoken', 1.0)],
#  u'my compensation': [(u'have', 1.0)],
#  u'causes the': [(u'missed', 1.0)],
#  u'me half': [(u'an', 1.0)],
#  u'dm been': [(u'on', 1.0)],
#  u'diego and': [(u'the', 0.5), (u'philadelphia', 0.5)],
#  u'of warning': [(u'or', 1.0)],
#  u'no more': [(u'faith', 0.045454545454545456),
#   (u'options', 0.045454545454545456),
#   (u'flights', 0.13636363636363635),
#   (u'done', 0.045454545454545456),
#   (u'hotel', 0.090909090909090912),
#   (u'chances', 0.045454545454545456),
#   (u'than', 0.090909090909090912),
#   (u'it', 0.045454545454545456),
#   (u'endtoken', 0.090909090909090912),
#   (u'delays', 0.090909090909090912),
#   (u'united', 0.045454545454545456),
#   (u'room', 0.13636363636363635),
#   (u'nonstops', 0.045454545454545456),
#   (u'aa', 0.045454545454545456)],
#  u'twice got': [(u'letter', 1.0)],
#  u'for when': [(u'our', 0.33333333333333331),
#   (u'view', 0.33333333333333331),
#   (u'come', 0.33333333333333331)],
#  u'night complaint': [(u'to', 1.0)],
#  u'enuf charge': [(u'me', 1.0)],
#  u'to find': [(u'lost', 0.017543859649122806),
#   (u'another', 0.017543859649122806),
#   (u'smoothie', 0.017543859649122806),
#   (u'hotel', 0.052631578947368418),
#   (u'flight', 0.035087719298245612),
#   (u'airfare', 0.017543859649122806),
#   (u'him', 0.035087719298245612),
#   (u'space', 0.017543859649122806),
#   (u'it', 0.035087719298245612),
#   (u'jobs', 0.017543859649122806),
#   (u'place', 0.017543859649122806),
#   (u'way', 0.017543859649122806),
#   (u'reasonably', 0.017543859649122806),
#   (u'decent', 0.017543859649122806),
#   (u'her', 0.017543859649122806),
#   (u'the', 0.070175438596491224),
#   (u'info', 0.017543859649122806),
#   (u'an', 0.017543859649122806),
#   (u'out', 0.24561403508771928),
#   (u'early', 0.017543859649122806),
#   (u'am', 0.017543859649122806),
#   (u'used', 0.017543859649122806),
#   (u'ana', 0.017543859649122806),
#   (u'parking', 0.017543859649122806),
#   (u'gate', 0.017543859649122806),
#   (u'options', 0.017543859649122806),
#   (u'them', 0.017543859649122806),
#   (u'new', 0.052631578947368418),
#   (u'anyone', 0.017543859649122806),
#   (u'my', 0.08771929824561403)],
#  u'those three': [(u'people', 1.0)],
#  u'toward lifetime': [(u'miles', 1.0)],
#  u'providing free': [(u'food', 1.0)],
#  u'now hr': [(u'late', 0.5), (u'delay', 0.5)],
#  u'unveils new': [(u'routes', 0.33333333333333331),
#   (u'bluemanity', 0.33333333333333331),
#   (u'flights', 0.33333333333333331)],
#  u'twice my': [(u'issue', 1.0)],
#  u'cc delta': [(u'endtoken', 1.0)],
#  u'got booked': [(u'on', 1.0)],
#  u'united lovely': [(u'new', 1.0)],
#  u'take minutes': [(u'to', 1.0)],
#  u'destinationdragons is': [(u'during', 1.0)],
#  u'flights but': [(u'never', 0.16666666666666666),
#   (u'also', 0.16666666666666666),
#   (u'chose', 0.16666666666666666),
#   (u'theres', 0.16666666666666666),
#   (u'can', 0.16666666666666666),
#   (u've', 0.16666666666666666)],
#  u'000 fine': [(u'still', 1.0)],
#  u'old alone': [(u'is', 1.0)],
#  u'perhaps better': [(u'client', 1.0)],
#  u'destinationdragons id': [(u'is', 1.0)],
#  u'terrible flight': [(u'experience', 1.0)],
#  u'destinationdragons in': [(u'slc', 0.5), (u'san', 0.5)],
#  u'named leah': [(u'that', 1.0)],
#  u'to same': [(u'city', 0.5), (u'damn', 0.5)],
#  u'report guys': [(u'endtoken', 1.0)],
#  u'service without': [(u'luggage', 0.5), (u'anyone', 0.5)],
#  u'phl east': [(u'checkin', 1.0)],
#  u'vp of': [(u'custexp', 1.0)],
#  u'frustrating kept': [(u'getting', 1.0)],
#  u'info she': [(u'assured', 1.0)],
#  u'screwed by': [(u'the', 1.0)],
#  u'horrible service': [(u'or', 0.1111111111111111),
#   (u'over', 0.1111111111111111),
#   (u'from', 0.1111111111111111),
#   (u'loganairports', 0.1111111111111111),
#   (u'again', 0.1111111111111111),
#   (u'for', 0.1111111111111111),
#   (u'endtoken', 0.22222222222222221),
#   (u'wrong', 0.1111111111111111)],
#  u'gso is': [(u'cancelled', 1.0)],
#  u'iah waiting': [(u'on', 1.0)],
#  u'wouldn describe': [(u'feces', 1.0)],
#  u'hold yesterday': [(u'gt', 1.0)],
#  u'at e11': [(u'be', 1.0)],
#  u'teco teco': [(u'reclameaqui', 1.0)],
#  u'true there': [(u'new', 1.0)],
#  u'china based': [(u'on', 1.0)],
#  u'is referred': [(u'to', 1.0)],
#  u'value remains': [(u'is', 1.0)],
#  u'and overcharge': [(u'you', 1.0)],
#  u'airplane seats': [(u'tray', 1.0)],
#  u'them appropriately': [(u'when', 1.0)],
#  u'pr class': [(u'would', 1.0)],
#  u'receiving poor': [(u'poor', 1.0)],
#  u'done may': [(u'be', 1.0)],
#  u'advantage united': [(u'endtoken', 1.0)],
#  u'flight watched': [(u'equalizer', 1.0)],
#  u'amsterdam snowstorm': [(u'endtoken', 1.0)],
#  u'just out': [(u'of', 0.5), (u'baggage', 0.5)],
#  u'pretty impressed': [(u'with', 1.0)],
#  u'jump for': [(u'an', 1.0)],
#  u'ignored our': [(u'plane', 1.0)],
#  u'scam but': [(u'scam', 1.0)],
#  u'bridge to': [(u'gate', 1.0)],
#  u'day since': [(u'sun', 0.5), (u'monday', 0.5)],
#  u'dca passengerslose': [(u'endtoken', 1.0)],
#  u'really lame': [(u'excuse', 1.0)],
#  u'and using': [(u'call', 1.0)],
#  u'ewr if': [(u'you', 1.0)],
#  u'aus cun': [(u'direct', 1.0)],
#  u'flown several': [(u'times', 1.0)],
#  u'usairways ha': [(u'flight', 0.5), (u'you', 0.5)],
#  u'wheel coming': [(u'off', 1.0)],
#  u'respond back': [(u'endtoken', 1.0)],
#  u'usairways he': [(u'is', 0.33333333333333331),
#   (u'overflowed', 0.33333333333333331),
#   (u'waited', 0.33333333333333331)],
#  u'become black': [(u'laptop', 1.0)],
#  u'email presidential': [(u'level', 1.0)],
#  u'usairways hi': [(u'there', 0.083333333333333329),
#   (u'on', 0.083333333333333329),
#   (u'can', 0.083333333333333329),
#   (u'again', 0.083333333333333329),
#   (u'have', 0.083333333333333329),
#   (u'could', 0.083333333333333329),
#   (u'you', 0.083333333333333329),
#   (u'in', 0.083333333333333329),
#   (u'im', 0.083333333333333329),
#   (u'is', 0.083333333333333329),
#   (u'guys', 0.16666666666666666)],
#  u'southwestair one': [(u'of', 0.5), (u'heck', 0.5)],
#  u'please take': [(u'your', 0.5), (u'me', 0.5)],
#  u'usairways hr': [(u'flight', 0.5), (u'wait', 0.5)],
#  u'on crazy': [(u'endtoken', 1.0)],
#  u'they dont': [(u'think', 0.5), (u'pick', 0.5)],
#  u'of stolen': [(u'goods', 1.0)],
#  u'abcnetwork how': [(u'are', 1.0)],
#  u'will actually': [(u'take', 1.0)],
#  u'min extra': [(u'because', 1.0)],
#  u'dealing fam': [(u'emergency', 1.0)],
#  u'pushing her': [(u'down', 1.0)],
#  u'trust get': [(u'lost', 1.0)],
#  u'usual great': [(u'flight', 1.0)],
#  u'usairways new': [(u'problem', 0.20000000000000001),
#   (u'tag', 0.20000000000000001),
#   (u'marketing', 0.20000000000000001),
#   (u'as', 0.20000000000000001),
#   (u'slogan', 0.20000000000000001)],
#  u'me go': [(u'home', 0.5), (u'to', 0.5)],
#  u'was weather': [(u'and', 0.5), (u'would', 0.5)],
#  u'seat not': [(u'good', 0.5), (u'acceptable', 0.5)],
#  u'not understand': [(u'the', 0.5), (u'endtoken', 0.5)],
#  u'seat now': [(u'bought', 0.5), (u'there', 0.5)],
#  u'brought the': [(u'plane', 1.0)],
#  u'instead of40': [(u'got', 1.0)],
#  u'aka more': [(u'delays', 1.0)],
#  u'total win': [(u'happy', 1.0)],
#  u'me doesn': [(u'work', 1.0)],
#  u'my 1st': [(u'flight', 0.16666666666666666),
#   (u'trip', 0.16666666666666666),
#   (u'class', 0.16666666666666666),
#   (u'reservation', 0.16666666666666666),
#   (u'choice', 0.16666666666666666),
#   (u'is', 0.16666666666666666)],
#  u'seat non': [(u'empty', 1.0)],
#  u'flight we': [(u'miss', 0.1111111111111111),
#   (u'paid', 0.1111111111111111),
#   (u'will', 0.1111111111111111),
#   (u're', 0.1111111111111111),
#   (u'were', 0.22222222222222221),
#   (u'then', 0.1111111111111111),
#   (u'hit', 0.1111111111111111),
#   (u'll', 0.1111111111111111)],
#  u'fax like': [(u'in', 1.0)],
#  u'prof_solutions be': [(u'prepared', 1.0)],
#  u'was never': [(u'really', 0.14285714285714285),
#   (u'scanned', 0.14285714285714285),
#   (u'given', 0.14285714285714285),
#   (u'asked', 0.14285714285714285),
#   (u'sent', 0.14285714285714285),
#   (u'able', 0.14285714285714285),
#   (u'resolved', 0.14285714285714285)],
#  u'yesterday sorted': [(u'now', 1.0)],
#  u'free bags': [(u'and', 1.0)],
#  u'flight wi': [(u'fi', 1.0)],
#  u'messages direct': [(u'private', 1.0)],
#  u'reevaluate my': [(u'nyc', 1.0)],
#  u'from ind': [(u'to', 1.0)],
#  u'dming you': [(u'that', 0.33333333333333331),
#   (u'now', 0.33333333333333331),
#   (u'ladies', 0.33333333333333331)],
#  u'but take': [(u'meds', 0.5), (u'either', 0.5)],
#  u'always wifiless': [(u'flight', 1.0)],
#  u'company we': [(u'merged', 1.0)],
#  u'you fix': [(u'it', 0.25), (u'this', 0.5), (u'your', 0.25)],
#  u'trip is': [(u'month', 0.16666666666666666),
#   (u'all', 0.16666666666666666),
#   (u'around', 0.16666666666666666),
#   (u'not', 0.16666666666666666),
#   (u'already', 0.16666666666666666),
#   (u'waste', 0.16666666666666666)],
#  u'at triflight': [(u'and', 1.0)],
#  u'trip in': [(u'late', 0.5), (u'april', 0.5)],
#  u'3hrs dead': [(u'phone', 1.0)],
#  u'password and': [(u'don', 1.0)],
#  u'boarded the': [(u'plane', 0.66666666666666663),
#   (u'cushions', 0.33333333333333331)],
#  u'joanna is': [(u'wonderful', 1.0)],
#  u'astounding https': [(u'co', 1.0)],
#  u'is us4623': [(u'going', 1.0)],
#  u'delay one': [(u'way', 1.0)],
#  u'for answering': [(u'my', 0.33333333333333331),
#   (u'me', 0.66666666666666663)],
#  u'bag go': [(u'to', 1.0)],
#  u'in atl': [(u'due', 0.25),
#   (u'southwestair', 0.25),
#   (u'amp', 0.25),
#   (u'girl', 0.25)],
#  u'on right': [(u'now', 0.66666666666666663),
#   (u'before', 0.33333333333333331)],
#  u'direct message': [(u'faster', 0.20000000000000001),
#   (u'you', 0.20000000000000001),
#   (u'if', 0.20000000000000001),
#   (u'me', 0.40000000000000002)],
#  u'll bring': [(u'whole', 1.0)],
#  u'present just': [(u'trying', 1.0)],
#  u'as last': [(u'name', 0.5), (u'week', 0.5)],
#  u'don use': [(u'passbook', 1.0)],
#  u'1ker friendlyskies': [(u'endtoken', 1.0)],
#  u'in atx': [(u'endtoken', 1.0)],
#  u'over everyone': [(u'on', 1.0)],
#  u'attendant as': [(u'one', 1.0)],
#  u'midnight then': [(u'say', 1.0)],
#  u'our seats': [(u'endtoken', 0.14285714285714285),
#   (u'to', 0.14285714285714285),
#   (u'away', 0.14285714285714285),
#   (u'we', 0.14285714285714285),
#   (u'changed', 0.14285714285714285),
#   (u'and', 0.14285714285714285),
#   (u'or', 0.14285714285714285)],
#  u'attendant at': [(u'newark', 0.5), (u'mccarran', 0.5)],
#  u'flights fort': [(u'lauderdale', 1.0)],
#  u'can compensate': [(u'with', 1.0)],
#  u'sure the': [(u'world', 0.5), (u'people', 0.5)],
#  u'into accepting': [(u'voucher', 1.0)],
#  u'overhead bag': [(u'as', 1.0)],
#  u'the so': [(u'below', 1.0)],
#  u'entertainment on': [(u'hr', 0.5), (u'your', 0.5)],
#  u'money by': [(u'opening', 1.0)],
#  u'dallas next': [(u'flight', 1.0)],
#  u'phoenix gave': [(u'ticks', 1.0)],
#  u'now counting': [(u'100', 0.5), (u'on', 0.5)],
#  u'tweet the': [(u'id', 1.0)],
#  u'connect but': [(u'our', 0.5), (u'customer', 0.5)],
#  u'on 2017': [(u'bos', 1.0)],
#  u'so can': [(u'share', 0.032786885245901641),
#   (u'wait', 0.016393442622950821),
#   (u'fly', 0.081967213114754092),
#   (u'have', 0.016393442622950821),
#   (u'get', 0.081967213114754092),
#   (u'go', 0.016393442622950821),
#   (u'tell', 0.032786885245901641),
#   (u'actually', 0.016393442622950821),
#   (u'jam', 0.016393442622950821),
#   (u'leave', 0.032786885245901641),
#   (u'rebook', 0.016393442622950821),
#   (u'follow', 0.016393442622950821),
#   (u'watch', 0.032786885245901641),
#   (u'just', 0.016393442622950821),
#   (u'dm', 0.22950819672131148),
#   (u'do', 0.016393442622950821),
#   (u'sit', 0.016393442622950821),
#   (u'book', 0.016393442622950821),
#   (u'call', 0.016393442622950821),
#   (u'make', 0.049180327868852458),
#   (u'complain', 0.016393442622950821),
#   (u'thank', 0.016393442622950821),
#   (u'speak', 0.016393442622950821),
#   (u'change', 0.016393442622950821),
#   (u'send', 0.049180327868852458),
#   (u'waste', 0.016393442622950821),
#   (u'live', 0.016393442622950821),
#   (u'buy', 0.032786885245901641),
#   (u'run', 0.016393442622950821),
#   (u'add', 0.016393442622950821),
#   (u'sell', 0.016393442622950821)],
#  u'but with': [(u'the', 0.16666666666666666),
#   (u'quantas', 0.16666666666666666),
#   (u'app', 0.16666666666666666),
#   (u'a3', 0.16666666666666666),
#   (u'poor', 0.16666666666666666),
#   (u'none', 0.16666666666666666)],
#  u'ticket why': [(u'endtoken', 0.5), (u'united', 0.5)],
#  u'since contacted': [(u'customer', 1.0)],
#  u'of those': [(u'flights', 0.14285714285714285),
#   (u'endtoken', 0.14285714285714285),
#   (u'that', 0.14285714285714285),
#   (u'you', 0.14285714285714285),
#   (u'103', 0.14285714285714285),
#   (u'being', 0.14285714285714285),
#   (u'experiences', 0.14285714285714285)],
#  u'passengers boarding': [(u'in', 1.0)],
#  u'790 dca': [(u'bos', 1.0)],
#  u'will follow': [(u'up', 0.66666666666666663),
#   (u'endtoken', 0.33333333333333331)],
#  u'mac and': [(u'ipad', 1.0)],
#  u'no hot': [(u'food', 1.0)],
#  u'sw fan': [(u'amp', 1.0)],
#  u'hours had': [(u'to', 1.0)],
#  u'dont respond': [(u'at', 1.0)],
#  u'first impressions': [(u'count', 0.5), (u'are', 0.5)],
#  u'dpt for': [(u'40', 1.0)],
#  u'short haul': [(u'airline', 1.0)],
#  u'lord heading': [(u'home', 1.0)],
#  u'rescheduled any': [(u'updates', 1.0)],
#  u'feels good': [(u'to', 1.0)],
#  u'last ever': [(u'flight', 1.0)],
#  u'contd they': [(u'put', 1.0)],
#  u'apple cr\xe2pe': [(u'amazing', 1.0)],
#  u'it close': [(u'to', 1.0)],
#  u'can need': [(u'get', 1.0)],
#  u'still shows': [(u'55', 0.25),
#   (u'it', 0.25),
#   (u'plenty', 0.25),
#   (u'on', 0.25)],
#  u'whereabouts unknown': [(u'greeeaat', 1.0)],
#  u'carriers when': [(u'all', 1.0)],
#  u'that to': [(u'me', 0.16666666666666666),
#   (u'find', 0.16666666666666666),
#   (u'be', 0.16666666666666666),
#   (u'the', 0.5)],
#  u'customer service': [(u'group', 0.0017793594306049821),
#   (u'counter', 0.0017793594306049821),
#   (u'placing', 0.0017793594306049821),
#   (u'open', 0.0017793594306049821),
#   (u'only', 0.0071174377224199285),
#   (u'rethinking', 0.0017793594306049821),
#   (u'ticket', 0.0017793594306049821),
#   (u'again', 0.0035587188612099642),
#   (u'stinks', 0.0017793594306049821),
#   (u'manager', 0.0035587188612099642),
#   (u've', 0.0071174377224199285),
#   (u'further', 0.0017793594306049821),
#   (u'or', 0.0017793594306049821),
#   (u'have', 0.0088967971530249119),
#   (u'trips', 0.0017793594306049821),
#   (u'they', 0.0017793594306049821),
#   (u'then', 0.0017793594306049821),
#   (u'experienced', 0.0017793594306049821),
#   (u'tried', 0.0017793594306049821),
#   (u'without', 0.0035587188612099642),
#   (u'lacks', 0.0017793594306049821),
#   (u'gate', 0.0017793594306049821),
#   (u'cancelled', 0.0017793594306049821),
#   (u'12', 0.0017793594306049821),
#   (u'30am', 0.0017793594306049821),
#   (u'flt', 0.0017793594306049821),
#   (u'runaround', 0.0017793594306049821),
#   (u'gets', 0.0017793594306049821),
#   (u'says', 0.0017793594306049821),
#   (u'lack', 0.0017793594306049821),
#   (u'displayed', 0.0017793594306049821),
#   (u'when', 0.0035587188612099642),
#   (u'clue', 0.0017793594306049821),
#   (u'usairways', 0.0017793594306049821),
#   (u'needs', 0.0017793594306049821),
#   (u'flying', 0.0017793594306049821),
#   (u'empty', 0.0017793594306049821),
#   (u'everyone', 0.0017793594306049821),
#   (u'from', 0.0035587188612099642),
#   (u'lou', 0.0017793594306049821),
#   (u'get', 0.0017793594306049821),
#   (u'deserves', 0.0017793594306049821),
#   (u'issues', 0.0017793594306049821),
#   (u'neveragain', 0.0035587188612099642),
#   (u'americanair', 0.0017793594306049821),
#   (u'trying', 0.0017793594306049821),
#   (u'found', 0.0017793594306049821),
#   (u'out', 0.0017793594306049821),
#   (u'can', 0.0053380782918149468),
#   (u'sorude', 0.0017793594306049821),
#   (u'people', 0.0017793594306049821),
#   (u'should', 0.0017793594306049821),
#   (u'too', 0.0017793594306049821),
#   (u'worstairline', 0.0017793594306049821),
#   (u'experience', 0.01601423487544484),
#   (u'area', 0.0017793594306049821),
#   (u'no', 0.0035587188612099642),
#   (u'sat', 0.0017793594306049821),
#   (u'calls', 0.0035587188612099642),
#   (u'still', 0.0017793594306049821),
#   (u'via', 0.0053380782918149468),
#   (u'delayed', 0.0035587188612099642),
#   (u'having', 0.0017793594306049821),
#   (u'incredible', 0.0017793594306049821),
#   (u'handler', 0.0017793594306049821),
#   (u'bags', 0.0017793594306049821),
#   (u'fail', 0.0035587188612099642),
#   (u'lax', 0.0017793594306049821),
#   (u'senseless', 0.0035587188612099642),
#   (u'doesn', 0.0017793594306049821),
#   (u'oh', 0.0017793594306049821),
#   (u'of', 0.0071174377224199285),
#   (u'representative', 0.0017793594306049821),
#   (u'by', 0.0035587188612099642),
#   (u'provides', 0.0017793594306049821),
#   (u'provided', 0.0035587188612099642),
#   (u'number', 0.0017793594306049821),
#   (u'worstcustomerserviceever', 0.0017793594306049821),
#   (u'makes', 0.0017793594306049821),
#   (u'yes', 0.0017793594306049821),
#   (u'first', 0.0017793594306049821),
#   (u'now', 0.0017793594306049821),
#   (u'not', 0.0017793594306049821),
#   (u'training', 0.0017793594306049821),
#   (u'reps', 0.0071174377224199285),
#   (u'rep', 0.02491103202846975),
#   (u'twice', 0.0017793594306049821),
#   (u'what', 0.0035587188612099642),
#   (u'll', 0.0017793594306049821),
#   (u'which', 0.0017793594306049821),
#   (u'bring', 0.0017793594306049821),
#   (u'shout', 0.0017793594306049821),
#   (u'kiosk', 0.0017793594306049821),
#   (u'flight', 0.0017793594306049821),
#   (u'instead', 0.0017793594306049821),
#   (u'favoriteairline', 0.0017793594306049821),
#   (u'leaves', 0.0017793594306049821),
#   (u'wrongfully', 0.0017793594306049821),
#   (u'after', 0.0035587188612099642),
#   (u'theydontanswer', 0.0017793594306049821),
#   (u'been', 0.0053380782918149468),
#   (u'on', 0.0071174377224199285),
#   (u'southwestair', 0.0017793594306049821),
#   (u'but', 0.0053380782918149468),
#   (u'overhaul', 0.0017793594306049821),
#   (u'department', 0.0053380782918149468),
#   (u'my', 0.0017793594306049821),
#   (u'for', 0.012455516014234875),
#   (u'going', 0.0017793594306049821),
#   (u'sitting', 0.0017793594306049821),
#   (u'care', 0.0017793594306049821),
#   (u'resolved', 0.0017793594306049821),
#   (u'ever', 0.023131672597864767),
#   (u'family', 0.0017793594306049821),
#   (u'eventually', 0.0017793594306049821),
#   (u'good', 0.0017793594306049821),
#   (u'wasn', 0.0017793594306049821),
#   (u'said', 0.0017793594306049821),
#   (u'the', 0.0035587188612099642),
#   (u'will', 0.0053380782918149468),
#   (u'today', 0.017793594306049824),
#   (u'got', 0.0017793594306049821),
#   (u'nomoreaggravation', 0.0017793594306049821),
#   (u'team', 0.010676156583629894),
#   (u'desk', 0.010676156583629894),
#   (u'was', 0.012455516014234875),
#   (u'dallas', 0.0017793594306049821),
#   (u'very', 0.0035587188612099642),
#   (u'guy', 0.0017793594306049821),
#   (u'as', 0.0017793594306049821),
#   (u'at', 0.032028469750889681),
#   (u'about', 0.0017793594306049821),
#   (u'professionals', 0.0017793594306049821),
#   (u'thanku', 0.0017793594306049821),
#   (u'nightmare', 0.0017793594306049821),
#   (u'love', 0.0017793594306049821),
#   (u'name', 0.0017793594306049821),
#   (u'to', 0.019572953736654804),
#   (u'line', 0.023131672597864767),
#   (u'site', 0.0017793594306049821),
#   (u'business', 0.0017793594306049821),
#   (u'exhibited', 0.0017793594306049821),
#   (u'one', 0.0017793594306049821),
#   (u'since', 0.0035587188612099642),
#   (u'right', 0.0053380782918149468),
#   (u'helping', 0.0017793594306049821),
#   (u'called', 0.0017793594306049821),
#   (u'endtoken', 0.13701067615658363),
#   (u'everywhere', 0.0017793594306049821),
#   (u'contact', 0.0071174377224199285),
#   (u'16hr', 0.0017793594306049821),
#   (u'flt635', 0.0017793594306049821),
#   (u'agent', 0.0088967971530249119),
#   (u'1hr', 0.0017793594306049821),
#   (u'never', 0.0053380782918149468),
#   (u'if', 0.0017793594306049821),
#   (u'has', 0.014234875444839857),
#   (u'staff', 0.0017793594306049821),
#   (u'question', 0.0017793594306049821),
#   (u'ment', 0.0017793594306049821),
#   (u'couldn', 0.0017793594306049821),
#   (u'left', 0.0017793594306049821),
#   (u'2day', 0.0017793594306049821),
#   (u'failure', 0.0017793594306049821),
#   (u'agents', 0.012455516014234875),
#   (u'united', 0.0035587188612099642),
#   (u'and', 0.030249110320284697),
#   (u'thank', 0.0071174377224199285),
#   (u'phone', 0.0071174377224199285),
#   (u'shotwest', 0.0017793594306049821),
#   (u'usairwaysfail', 0.0017793594306049821),
#   (u'cannedtweet', 0.0017793594306049821),
#   (u'in', 0.012455516014234875),
#   (u'is', 0.087188612099644125),
#   (u'32', 0.0017793594306049821),
#   (u'that', 0.0053380782918149468),
#   (u'bible', 0.0017793594306049821),
#   (u'huh', 0.0017793594306049821),
#   (u'means', 0.0035587188612099642),
#   (u'thru', 0.0017793594306049821),
#   (u'thanks', 0.0053380782918149468),
#   (u'folks', 0.0017793594306049821),
#   (u'because', 0.0017793594306049821),
#   (u'point', 0.0017793594306049821),
#   (u'terrible', 0.0017793594306049821),
#   (u'abysmal', 0.0017793594306049821),
#   (u'http', 0.0053380782918149468),
#   (u'amp', 0.0088967971530249119),
#   (u'calling', 0.0017793594306049821),
#   (u'please', 0.0017793594306049821),
#   (u'you', 0.014234875444839857),
#   (u'forwarding', 0.0017793594306049821),
#   (u'this', 0.0053380782918149468),
#   (u'finally', 0.0035587188612099642),
#   (u'who', 0.0035587188612099642),
#   (u'why', 0.0017793594306049821),
#   (u'dont', 0.0017793594306049821),
#   (u'so', 0.0017793594306049821),
#   (u'like', 0.0035587188612099642),
#   (u'disappointed', 0.0017793594306049821),
#   (u'irresponsible', 0.0017793594306049821),
#   (u'issue', 0.0017793594306049821),
#   (u'astounds', 0.0017793594306049821),
#   (u'sucks', 0.0088967971530249119),
#   (u'mean', 0.0017793594306049821),
#   (u'yesterday', 0.0017793594306049821)],
#  u'americanair toby': [(u'hates', 1.0)],
#  u'had hard': [(u'time', 1.0)],
#  u'of ps': [(u'driving', 1.0)],
#  u'sld out': [(u'anytime', 1.0)],
#  u'since sun': [(u'to', 1.0)],
#  u'flight tried': [(u'to', 1.0)],
#  u'nice save': [(u'endtoken', 1.0)],
#  u'705 fra': [(u'cat', 1.0)],
#  u'help baby': [(u'hannah', 1.0)],
#  u'prevent you': [(u'from', 1.0)],
#  u'stop amp': [(u'give', 1.0)],
#  u'flown now': [(u'you', 1.0)],
#  u'27 from': [(u'jfk', 0.5), (u'jkf', 0.5)],
#  u'is easy': [(u'for', 0.5), (u'to', 0.5)],
#  u'given up': [(u'endtoken', 1.0)],
#  u'exactly it': [(u'states', 1.0)],
#  u'love missing': [(u'an', 1.0)],
#  u'jetblue missing': [(u'it', 1.0)],
#  u'airport ramada': [(u'without', 1.0)],
#  u'are on': [(u'flight', 0.050000000000000003),
#   (u'2424', 0.050000000000000003),
#   (u'vacation', 0.050000000000000003),
#   (u'the', 0.25),
#   (u'their', 0.050000000000000003),
#   (u'standby', 0.050000000000000003),
#   (u'hours', 0.050000000000000003),
#   (u'time', 0.050000000000000003),
#   (u'three', 0.050000000000000003),
#   (u'aa3195', 0.050000000000000003),
#   (u'all', 0.050000000000000003),
#   (u'ua1481', 0.050000000000000003),
#   (u'us', 0.050000000000000003),
#   (u'two', 0.050000000000000003),
#   (u'day', 0.050000000000000003),
#   (u'hold', 0.050000000000000003)],
#  u'are ok': [(u'with', 1.0)],
#  u'needs prayer': [(u'disappointed', 1.0)],
#  u'overhead the': [(u'size', 1.0)],
#  u'does ski': [(u'bag', 1.0)],
#  u'mileage credits': [(u'endtoken', 1.0)],
#  u'35x nationalairpor': [(u'nothin', 1.0)],
#  u'yr ppl': [(u'3x', 1.0)],
#  u'exactly is': [(u'endtoken', 1.0)],
#  u'market will': [(u'have', 1.0)],
#  u'acct its': [(u'gone', 1.0)],
#  u'treated like': [(u'nobody', 0.33333333333333331),
#   (u'crap', 0.33333333333333331),
#   (u'garbage', 0.33333333333333331)],
#  u'commence new': [(u'policies', 1.0)],
#  u'friendly efficient': [(u'air', 0.5), (u'awesome', 0.5)],
#  u'of their': [(u'customers', 0.16666666666666666),
#   (u'control', 0.083333333333333329),
#   (u'skilled', 0.083333333333333329),
#   (u'planes', 0.083333333333333329),
#   (u'flights', 0.083333333333333329),
#   (u'cancelled', 0.083333333333333329),
#   (u'instruments', 0.083333333333333329),
#   (u'ticket', 0.083333333333333329),
#   (u'asses', 0.083333333333333329),
#   (u'names', 0.083333333333333329),
#   (u'hands', 0.083333333333333329)],
#  u'phl bag': [(u'claim', 0.5), (u'check', 0.5)],
#  u'understand pricing': [(u'flying', 1.0)],
#  u'full fight': [(u'ticket', 1.0)],
#  u'waiting again': [(u'to', 1.0)],
#  u'to touchdown': [(u'moodlitmonday', 1.0)],
#  u'our conversation': [(u'is', 1.0)],
#  u'americanair congrats': [(u'on', 1.0)],
#  u'for these': [(u'seats', 0.5), (u'situations', 0.5)],
#  u'attitudes toward': [(u'helping', 1.0)],
#  u'or lost': [(u'will', 1.0)],
#  u'neveragain flywhonotblue': [(u'endtoken', 1.0)],
#  u'only needed': [(u'wheel', 0.5), (u'to', 0.5)],
#  u'couldn see': [(u'my', 1.0)],
#  u'doesn reflect': [(u'the', 1.0)],
#  u'why offer': [(u'automated', 0.5), (u'the', 0.5)],
#  u'departure on': [(u'21', 0.5), (u'potus', 0.5)],
#  u'no status': [(u'get', 1.0)],
#  u'my businessfirst': [(u'priority', 1.0)],
#  u'was returned': [(u'in', 1.0)],
#  u'might afford': [(u'you', 1.0)],
#  u'avail online': [(u'for', 1.0)],
#  u'departure of': [(u'45pm', 0.16666666666666666),
#   (u'the', 0.16666666666666666),
#   (u'flite', 0.16666666666666666),
#   (u'55pm', 0.16666666666666666),
#   (u'4125', 0.16666666666666666),
#   (u'vx', 0.16666666666666666)],
#  u'they inquire': [(u'and', 1.0)],
#  u'flight baggage': [(u'and', 0.5), (u'more', 0.5)],
#  u'1220 right': [(u'now', 1.0)],
#  u'expedia call': [(u'wait', 1.0)],
#  u'of lifetime': [(u'destinationdragons', 0.5), (u'to', 0.5)],
#  u'sure email': [(u'screenshot', 1.0)],
#  u'hangup my': [(u'customerservice', 1.0)],
#  u'san like': [(u'most', 1.0)],
#  u'biceps wouldn': [(u'stow', 1.0)],
#  u'changes into': [(u'the', 1.0)],
#  u'arriving gate': [(u'of', 1.0)],
#  u'cak feb': [(u'18', 1.0)],
#  u'bring purse': [(u'tired', 1.0)],
#  u'like boss': [(u'sosmart', 0.5), (u'jetbluefame', 0.5)],
#  u'them every': [(u'way', 1.0)],
#  u'americanair souljacoy': [(u'what', 1.0)],
#  u'threatens canadian': [(u'cust', 1.0)],
#  u'things entertaining': [(u'endtoken', 1.0)],
#  u'southwest and': [(u'her', 0.25),
#   (u'payton', 0.25),
#   (u'all', 0.25),
#   (u'recommend', 0.25)],
#  u'under two': [(u'weeks', 1.0)],
#  u'for pm': [(u'endtoken', 1.0)],
#  u'getting is': [(u'maybe', 1.0)],
#  u'she loves': [(u'flying', 1.0)],
#  u'getting it': [(u'delivered', 1.0)],
#  u're almost': [(u'as', 1.0)],
#  u'for before': [(u'departure', 1.0)],
#  u'southwestair fox8news': [(u'serious', 1.0)],
#  u'method also': [(u'that', 1.0)],
#  u'fly back': [(u'to', 0.66666666666666663),
#   (u'thru', 0.16666666666666666),
#   (u'from', 0.16666666666666666)],
#  u'on aa111': [(u'how', 1.0)],
#  u'cle offered': [(u'one', 1.0)],
#  u'diverged to': [(u'burlington', 1.0)],
#  u'friday yet': [(u'endtoken', 1.0)],
#  u't3 lax': [(u'flight', 1.0)],
#  u'getting in': [(u'okay', 0.5), (u'until', 0.5)],
#  u'jetblue ll': [(u'read', 0.20000000000000001),
#   (u'pass', 0.20000000000000001),
#   (u'see', 0.20000000000000001),
#   (u'give', 0.20000000000000001),
#   (u'take', 0.20000000000000001)],
#  u'expensive for': [(u'people', 1.0)],
#  u'60 of': [(u'your', 1.0)],
#  u'answer guess': [(u'the', 1.0)],
#  u'longbeachcity to': [(u'establish', 1.0)],
#  u'day 11': [(u'trying', 1.0)],
#  u'project thetakeover': [(u'produced', 1.0)],
#  u'nrhodes85 look': [(u'another', 1.0)],
#  u'untz like': [(u'this', 1.0)],
#  u'can quit': [(u'you', 1.0)],
#  u'read ya': [(u'we', 1.0)],
#  u'been driving': [(u'across', 1.0)],
#  u'bulkhead seats': [(u'cannot', 1.0)],
#  u'day treated': [(u'me', 1.0)],
#  u'united battierccipuppy': [(u'your', 0.5), (u'we', 0.5)],
#  u'from neurosurgery': [(u'icu', 1.0)],
#  u'responses and': [(u'don', 1.0)],
#  u'speak united': [(u'vp', 1.0)],
#  u'jetblue lmfao': [(u'love', 0.5), (u'endtoken', 0.5)],
#  u'fist bump': [(u'high', 1.0)],
#  u'hate this': [(u'airline', 1.0)],
#  u'be issued': [(u'endtoken', 1.0)],
#  u'me set': [(u'up', 1.0)],
#  u'displeased with': [(u'the', 1.0)],
#  u'reconsidering my': [(u'flight', 1.0)],
#  u'hand right': [(u'endtoken', 1.0)],
#  u'email us': [(u'on', 1.0)],
#  u'and minutes': [(u'ago', 0.5), (u'just', 0.5)],
#  u'you either': [(u'overbook', 1.0)],
#  u'hold hr': [(u'27', 1.0)],
#  u'horrible oscars2015': [(u'endtoken', 1.0)],
#  u'are screwed': [(u'thanks', 1.0)],
#  u'1898 http': [(u'co', 1.0)],
#  u'sure but': [(u'different', 0.33333333333333331),
#   (u'the', 0.33333333333333331),
#   (u'my', 0.33333333333333331)],
#  u'cover change': [(u'fee', 1.0)],
#  u'quite put': [(u'my', 1.0)],
#  u'236 was': [(u'great', 1.0)],
#  u'terribleservice noservice': [(u'endtoken', 1.0)],
#  u'sorry received': [(u'from', 1.0)],
#  u'movie flight': [(u'endtoken', 1.0)],
#  u'stink flight': [(u'cancelled', 1.0)],
#  u'reps available': [(u'to', 1.0)],
#  u'is email': [(u'confirmation', 1.0)],
#  u'my adapted': [(u'seat', 1.0)],
#  u'hold cancelled': [(u'flights', 1.0)],
#  u'6500 for': [(u'biz', 1.0)],
#  u'if 5238': [(u'from', 1.0)],
#  u'available after': [(u'submitting', 1.0)],
# ...
#   (u'airways', 0.0090996168582375483),
#   (u'glitches', 0.00047892720306513407),
#   (u'credit', 0.00047892720306513407),
#   (u'ever', 0.00047892720306513407),
#   (u'maatkare67', 0.00047892720306513407),
#   (u'drwinston001', 0.00047892720306513407),
#   (u'claims', 0.00047892720306513407),
#   (u'perhaps', 0.00047892720306513407),
#   (u'ha', 0.00047892720306513407),
#   (u'would', 0.010057471264367816),
#   (u'sooo', 0.00047892720306513407),
#   (u'lopezlaymari', 0.00047892720306513407),
#   (u'travel', 0.00047892720306513407),
#   (u'americanair', 0.00047892720306513407),
#   (u'hear', 0.00095785440613026815),
#   (u'extra', 0.00047892720306513407),
#   (u'ticket', 0.00047892720306513407),
#   (u'clear', 0.00047892720306513407),
#   (u'stop', 0.00047892720306513407),
#   (u'aisles', 0.00047892720306513407),
#   (u'southwestair', 0.00047892720306513407),
#   (u'rocking', 0.00047892720306513407),
#   (u'go', 0.0014367816091954023),
#   (u'alittle', 0.00047892720306513407),
#   (u'help', 0.00047892720306513407),
#   (u'waited', 0.0014367816091954023),
#   (u'fail', 0.00047892720306513407),
#   (u'airline', 0.00047892720306513407),
#   (u'did', 0.0057471264367816091),
#   (u'service', 0.00095785440613026815),
#   (u'162', 0.00047892720306513407),
#   (u'landed', 0.00047892720306513407),
#   (u'said', 0.00095785440613026815),
#   (u'yup', 0.0019157088122605363),
#   (u'love', 0.0062260536398467429),
#   (u'there', 0.0028735632183908046),
#   (u'jannasaurusrex', 0.00047892720306513407),
#   (u'change', 0.00047892720306513407),
#   (u'flyfi', 0.00047892720306513407),
#   (u'little', 0.00047892720306513407),
#   (u'domestic', 0.00047892720306513407),
#   (u'plan', 0.00047892720306513407),
#   (u'anywhere', 0.0014367816091954023),
#   (u'philly', 0.00047892720306513407),
#   (u'window', 0.00047892720306513407),
#   (u'roxydigital', 0.00095785440613026815),
#   (u'terrible', 0.00047892720306513407),
#   (u'dca', 0.00047892720306513407),
#   (u'who', 0.0014367816091954023),
#   (u'why', 0.016762452107279693),
#   (u'havana', 0.00047892720306513407),
#   (u'understand', 0.0023946360153256703),
#   (u'dispatcher', 0.00047892720306513407),
#   (u'while', 0.00095785440613026815),
#   (u'gary', 0.00047892720306513407),
#   (u'kylecomer_', 0.00047892720306513407),
#   (u'gotcha', 0.00095785440613026815),
#   (u'already', 0.00047892720306513407),
#   (u'minutes', 0.00047892720306513407),
#   (u'finleybklyncfs', 0.00047892720306513407),
#   (u'flite454', 0.00047892720306513407),
#   (u'yesterday', 0.00095785440613026815),
#   (u'sylvie75015', 0.00047892720306513407),
#   (u'think', 0.0019157088122605363),
#   (u'learning', 0.00047892720306513407),
#   (u'such', 0.00047892720306513407),
#   (u'suck', 0.0014367816091954023),
#   (u'your', 0.0071839080459770114),
#   (u'hmmm', 0.00047892720306513407),
#   (u'hours', 0.00047892720306513407),
#   (u'felt', 0.00047892720306513407),
#   (u'same', 0.00047892720306513407),
#   (u'my', 0.011015325670498084),
#   (u'me', 0.00047892720306513407),
#   (u'boarding', 0.00047892720306513407),
#   (u'note', 0.00047892720306513407),
#   (u'shout', 0.00047892720306513407),
#   (u'absolutely', 0.0014367816091954023),
#   (u'took', 0.00047892720306513407),
#   (u'611', 0.00047892720306513407),
#   (u'things', 0.00047892720306513407),
#   (u'airbusintheus', 0.00047892720306513407),
#   (u'flight1407', 0.00047892720306513407),
#   (u'you', 0.026340996168582376),
#   (u'a320', 0.00047892720306513407),
#   (u'flt1533', 0.00047892720306513407),
#   (u'loved', 0.00047892720306513407),
#   (u'becomes', 0.00047892720306513407),
#   (u'loves', 0.00095785440613026815),
#   (u'with', 0.00095785440613026815),
#   (u'dropped', 0.00047892720306513407),
#   (u'thought', 0.00095785440613026815),
#   (u'tomorrow', 0.00047892720306513407),
#   (u'awww', 0.00095785440613026815),
#   (u'vincenzolandino', 0.00047892720306513407),
#   (u'offering', 0.00047892720306513407),
#   (u'time', 0.00047892720306513407),
#   (u'ahoy', 0.00047892720306513407),
#   (u'dropping', 0.00047892720306513407),
#   (u'can', 0.014846743295019157),
#   (u'need', 0.0014367816091954023),
#   (u'mon', 0.00047892720306513407),
#   (u'connecticut', 0.00047892720306513407),
#   (u'last', 0.0014367816091954023),
#   (u'lipstick', 0.00047892720306513407),
#   (u'thank', 0.025862068965517241),
#   (u'cinziannap', 0.00047892720306513407),
#   (u'punta', 0.00047892720306513407),
#   (u'promo', 0.00047892720306513407),
#   (u'denver', 0.00047892720306513407),
#   (u'pls', 0.00095785440613026815),
#   (u'lekvhg', 0.00047892720306513407),
#   (u'short', 0.00047892720306513407),
#   (u'making', 0.00047892720306513407),
#   (u'hanneslohmann', 0.00047892720306513407),
#   (u'figured', 0.00095785440613026815),
#   (u'kids', 0.00047892720306513407),
#   (u'worked', 0.00047892720306513407),
#   (u'kudos', 0.00095785440613026815),
#   (u'upset', 0.00047892720306513407),
#   (u'digg', 0.00047892720306513407),
#   (u'jeff_hofmann', 0.00047892720306513407),
#   (u'so', 0.0067049808429118776),
#   (u'disappointed', 0.0019157088122605363),
#   (u'being', 0.00095785440613026815),
#   (u'incredible', 0.00047892720306513407),
#   (u'when', 0.0071839080459770114),
#   (u'how', 0.0076628352490421452),
#   (u'utah', 0.00047892720306513407),
#   (u'some', 0.00047892720306513407),
#   (u'amagrino', 0.00047892720306513407)],
#  u'for 3rd': [(u'need', 0.33333333333333331), (u'time', 0.66666666666666663)],
#  u'say your': [(u'handling', 1.0)],
#  u'too unacceptable': [(u'endtoken', 1.0)],
#  u'advised gas': [(u'and', 1.0)],
#  u'waiting thanks': [(u'for', 1.0)],
#  u'baggage baggageissues': [(u'smh', 1.0)],
#  u'for of': [(u'my', 0.33333333333333331),
#   (u'us', 0.33333333333333331),
#   (u'those', 0.33333333333333331)],
#  u'be repaid': [(u'for', 1.0)],
#  u'delays due': [(u'to', 1.0)],
#  u'ur supervisors': [(u'suck', 1.0)],
#  u'is rett': [(u'cavan', 1.0)],
#  u'for on': [(u'tuesday', 1.0)],
#  u'else reservation': [(u'rr', 1.0)],
#  u'flight before': [(u'it', 0.33333333333333331),
#   (u'but', 0.66666666666666663)],
#  u'money it': [(u'is', 0.5), (u'about', 0.5)],
#  u'money without': [(u'notice', 1.0)],
#  u'blatant disregard': [(u'for', 1.0)],
#  u'when spent': [(u'night', 1.0)],
#  u'disrespectfully and': [(u'lied', 1.0)],
#  u'feature why': [(u'was', 1.0)],
#  u'emailed several': [(u'times', 1.0)],
#  u'plane longer': [(u'than', 1.0)],
#  u'crew he': [(u'just', 1.0)],
#  u'atlantic ploughs': [(u'lone', 1.0)],
#  u'cancld she': [(u'can', 1.0)],
#  u'wasted my': [(u'time', 0.5), (u'work', 0.5)],
#  u'lisa liza': [(u'in', 1.0)],
#  u'flightation and': [(u'then', 1.0)],
#  u'americanair here': [(u'you', 0.16666666666666666),
#   (u'standing', 0.16666666666666666),
#   (u'is', 0.5),
#   (u'we', 0.16666666666666666)],
#  u'3359 which': [(u'you', 1.0)],
#  u'you shouldn': [(u'make', 0.33333333333333331),
#   (u'page', 0.33333333333333331),
#   (u'use', 0.33333333333333331)],
#  u'fees to': [(u'rebook', 0.20000000000000001),
#   (u'sit', 0.40000000000000002),
#   (u'change', 0.40000000000000002)],
#  u'bus on': [(u'runway', 1.0)],
#  u'would communicate': [(u'more', 1.0)],
#  u'you shoulda': [(u'used', 1.0)],
#  u'heavy call': [(u'volume', 1.0)],
#  u'huge mistake': [(u'on', 1.0)],
#  u'modifications to': [(u'my', 1.0)],
#  u'says all': [(u'are', 1.0)],
#  u'cc miles': [(u'aren', 1.0)],
#  u'such waste': [(u'of', 1.0)],
#  u'sooo late': [(u'flight', 1.0)],
#  u'30 even': [(u'there', 1.0)],
#  u'wasn late': [(u'flight', 1.0)],
#  u'record from': [(u'you', 1.0)],
#  u'me only': [(u'canadian', 1.0)],
#  u'dal 00pm': [(u'none', 1.0)],
#  u'time gave': [(u'up', 1.0)],
#  u'thank all': [(u'for', 1.0)],
#  u'see yall': [(u'ballin', 1.0)],
#  u'it robyn': [(u'in', 1.0)],
#  u'2015 it': [(u'will', 1.0)],
#  u'actually either': [(u'call', 1.0)],
#  u'us brand': [(u'on', 1.0)],
#  u'wonderful global': [(u'first', 1.0)],
#  u'itinerary confirmation': [(u'email', 1.0)],
#  u'cmfat35000feet http': [(u'co', 1.0)],
#  u'morning should': [(u'change', 1.0)],
#  u'the 736': [(u'flight', 1.0)],
#  u'the 737': [(u'are', 1.0)],
#  u'actually have': [(u'any', 0.5), (u'brain', 0.5)],
#  u'baggage claims': [(u'in', 0.5), (u'when', 0.5)],
#  u'today still': [(u'no', 1.0)],
#  u'while but': [(u'they', 1.0)],
#  u'the 738': [(u'row', 1.0)],
#  u'message paper': [(u'tickets', 1.0)],
#  u'important why': [(u'did', 1.0)],
#  u'just ridiculous': [(u'endtoken', 0.5), (u'keep', 0.5)],
#  u'pvd when': [(u'you', 1.0)],
#  u'pulse http': [(u'co', 1.0)],
#  u'of ticket': [(u'endtoken', 0.33333333333333331),
#   (u'and', 0.33333333333333331),
#   (u'help', 0.33333333333333331)],
#  u'member does': [(u'my', 1.0)],
#  u'email addresses': [(u'to', 1.0)],
#  u'full fa': [(u'filed', 1.0)],
#  u'of ticked': [(u'off', 1.0)],
#  u'issue me': [(u'new', 1.0)],
#  u'calling usairwaysfail': [(u'americanair', 1.0)],
#  u'unless speak': [(u'to', 1.0)],
#  u'word if': [(u'you', 1.0)],
#  u'condom rito': [(u'family', 1.0)],
#  u'co rhw78ktqfo': [(u'endtoken', 1.0)],
#  u'planes second': [(u'flight', 1.0)],
#  u'scotch on': [(u'the', 1.0)],
#  u'your twitter': [(u'response', 0.20000000000000001),
#   (u'account', 0.20000000000000001),
#   (u'how', 0.20000000000000001),
#   (u'feed', 0.20000000000000001),
#   (u'appreciates', 0.20000000000000001)],
#  u'usairways 502': [(u'phx', 1.0)],
#  u'happens slc': [(u'ground', 1.0)],
#  u'cannot believe': [(u'the', 0.5), (u'how', 0.25), (u'this', 0.25)],
#  u'but lying': [(u'and', 1.0)],
#  u'do maintenance': [(u'endtoken', 0.5), (u'on', 0.5)],
#  u'outbound that': [(u'departs', 1.0)],
#  u'for lga': [(u'endtoken', 0.5), (u'not', 0.5)],
#  u'scheduled 00': [(u'pm', 1.0)],
#  u'den cle': [(u'because', 1.0)],
#  u'claim so': [(u'sad', 1.0)],
#  u'calling right': [(u'now', 1.0)],
#  u'until 1225': [(u'am', 1.0)],
#  u'automobiles gate': [(u'workers', 1.0)],
#  u'have at': [(u'least', 0.5), (u'the', 0.5)],
#  u'priced alternative': [(u'endtoken', 1.0)],
#  u'shot to': [(u'you', 0.5), (u'see', 0.5)],
#  u'experiences with': [(u'customer', 1.0)],
#  u'coat unfortunately': [(u'yes', 1.0)],
#  u'gate long': [(u'time', 1.0)],
#  u'well to': [(u'late', 0.5), (u'the', 0.5)],
#  u'sorry after': [(u'hrs', 1.0)],
#  u'offer an': [(u'earlier', 1.0)],
#  u'just bug': [(u'report', 1.0)],
#  u'tomorrow it': [(u'250', 1.0)],
#  u'tomorrow is': [(u'this', 0.25),
#   (u'weather', 0.25),
#   (u'cancelled', 0.25),
#   (u'there', 0.25)],
#  u'needs cabaret': [(u'singer', 1.0)],
#  u'friendly customer': [(u'service', 1.0)],
#  u'skis will': [(u'go', 1.0)],
#  u'day window': [(u'but', 0.5), (u'endtoken', 0.5)],
#  u'when answer': [(u'help', 1.0)],
#  u'virginamerica dad': [(u'on', 1.0)],
#  u'tomorrow in': [(u'utah', 0.5), (u'aa', 0.5)],
#  u'united deceptive': [(u'marketing', 1.0)],
#  u'bestairline nofilterneeded': [(u'amp', 1.0)],
#  u'did reach': [(u'out', 1.0)],
#  u'vegan meals': [(u'can', 1.0)],
#  u'from some': [(u'other', 1.0)],
#  u'upgrade exp': [(u'members', 1.0)],
#  u'conditions at': [(u'grk', 1.0)],
#  u'could screw': [(u'us', 1.0)],
#  u'holidays we': [(u're', 1.0)],
#  u'premier gold': [(u'desk', 1.0)],
#  u'of closer': [(u'hartford', 1.0)],
#  u'fr cancun': [(u'undefined', 1.0)],
#  u'joke toyingwithouremotions': [(u'endtoken', 1.0)],
#  u'flight 3899': [(u'hou', 1.0)],
#  u'on virgin': [(u'endtoken', 1.0)],
#  u'delta the': [(u'only', 1.0)],
#  u'my social': [(u'media', 1.0)],
#  u'000 for': [(u'my', 1.0)],
#  u'old school': [(u'ride', 1.0)],
#  u'you let': [(u'me', 0.46153846153846156),
#   (u'us', 0.076923076923076927),
#   (u'one', 0.076923076923076927),
#   (u'your', 0.076923076923076927),
#   (u'it', 0.076923076923076927),
#   (u'people', 0.15384615384615385),
#   (u'them', 0.076923076923076927)],
#  u'the hipster': [(u'innovation', 1.0)],
#  u'these cancelled': [(u'flightlations', 1.0)],
#  u'seems strange': [(u'to', 1.0)],
#  u'to weeks': [(u'endtoken', 0.5), (u'unacceptable', 0.5)],
#  u'exactly timely': [(u'data', 1.0)],
#  u'americanair cyncyn661': [(u'are', 1.0)],
#  u'after get': [(u'through', 1.0)],
#  u'awards weather': [(u'relate', 1.0)],
#  u'made fantastic': [(u'by', 1.0)],
#  u'speaking languages': [(u'paid', 1.0)],
#  u'delay killing': [(u'me', 1.0)],
#  u'try right': [(u'endtoken', 1.0)],
#  u'because want': [(u'to', 1.0)],
#  u'spirit look': [(u'like', 1.0)],
#  u'phone wait': [(u'times', 0.2857142857142857),
#   (u'was', 0.14285714285714285),
#   (u'amp', 0.14285714285714285),
#   (u'time', 0.42857142857142855)],
#  u'2015 cmh': [(u'oak', 1.0)],
#  u'chicago gate': [(u'k20', 1.0)],
#  u'agents had': [(u'no', 0.5), (u'rebooked', 0.5)],
#  u'heat ohno': [(u'bundleup', 1.0)],
#  u'im frequent': [(u'flyer', 1.0)],
#  u'tarmac also': [(u'lost', 1.0)],
#  u'please seat': [(u'us', 1.0)],
#  u'did you': [(u'receive', 0.022727272727272728),
#   (u'save', 0.022727272727272728),
#   (u'call', 0.022727272727272728),
#   (u'guys', 0.045454545454545456),
#   (u'seriously', 0.022727272727272728),
#   (u'mean', 0.022727272727272728),
#   (u'do', 0.022727272727272728),
#   (u'have', 0.068181818181818177),
#   (u'overbook', 0.022727272727272728),
#   (u'pick', 0.022727272727272728),
#   (u'know', 0.13636363636363635),
#   (u'read', 0.022727272727272728),
#   (u'screwed', 0.022727272727272728),
#   (u'pack', 0.022727272727272728),
#   (u'reschedule', 0.022727272727272728),
#   (u'load', 0.022727272727272728),
#   (u'just', 0.022727272727272728),
#   (u'cancelled', 0.11363636363636363),
#   (u'not', 0.022727272727272728),
#   (u'give', 0.022727272727272728),
#   (u'rebook', 0.022727272727272728),
#   (u'really', 0.022727272727272728),
#   (u'interupt', 0.022727272727272728),
#   (u'find', 0.022727272727272728),
#   (u'put', 0.022727272727272728),
#   (u'get', 0.068181818181818177),
#   (u'book', 0.022727272727272728),
#   (u'drop', 0.022727272727272728),
#   (u'try', 0.022727272727272728),
#   (u'discontinue', 0.022727272727272728)],
#  u'be frustrated': [(u'after', 0.25),
#   (u'compensate', 0.25),
#   (u'thank', 0.25),
#   (u'don', 0.25)],
#  u'incorrectly after': [(u'flight', 1.0)],
#  u'pr3oebc2n2 lol': [(u'wut', 1.0)],
#  u'now system': [(u'hung', 1.0)],
#  u'oh because': [(u'when', 1.0)],
#  u'americanair see': [(u'photo', 1.0)],
#  u'have real': [(u'email', 1.0)],
#  u'b4 it': [(u'was', 1.0)],
#  u'americanair gate': [(u'agents', 0.5), (u'agent', 0.5)],
#  u'dm convo': [(u'for', 1.0)],
#  u'my cats': [(u'missed', 0.5), (u'dead', 0.25), (u'flight', 0.25)],
#  u'disconnected customer': [(u'relations', 1.0)],
#  u'the clown': [(u'car', 1.0)],
#  u'frontier is': [(u'currently', 1.0)],
#  u'stellar just': [(u'not', 1.0)],
#  u'up big': [(u'1st', 1.0)],
#  u'saying sorry': [(u'endtoken', 1.0)],
#  u'person found': [(u'it', 1.0)],
#  u'leave his': [(u'bags', 1.0)],
#  u'without crew': [(u'here', 1.0)],
#  u'and already': [(u'had', 1.0)],
#  u'century are': [(u'we', 1.0)],
#  u'get supv': [(u'endtoken', 1.0)],
#  u'usairways disappointed': [(u'with', 1.0)],
#  u'past days': [(u'and', 0.5),
#   (u'with', 0.16666666666666666),
#   (u'has', 0.16666666666666666),
#   (u'endtoken', 0.16666666666666666)],
#  u'from vail': [(u'eagle', 1.0)],
#  u'out seats': [(u'and', 1.0)],
#  u'44 countries': [(u've', 1.0)],
#  u'using same': [(u'confirmation', 0.5), (u'gate', 0.5)],
#  u'plane but': [(u'why', 0.1111111111111111),
#   (u'gotta', 0.1111111111111111),
#   (u'thanks', 0.1111111111111111),
#   (u'united', 0.1111111111111111),
#   (u'the', 0.1111111111111111),
#   (u'no', 0.1111111111111111),
#   (u'that', 0.1111111111111111),
#   (u'was', 0.1111111111111111),
#   (u'can', 0.1111111111111111)],
#  u'response sorry': [(u'for', 1.0)],
#  u'cgroup help': [(u'endtoken', 1.0)],
#  u'southwestair fortunemagazine': [(u'always', 0.083333333333333329),
#   (u'great', 0.083333333333333329),
#   (u'love', 0.25),
#   (u'friendliest', 0.083333333333333329),
#   (u'superb', 0.083333333333333329),
#   (u'congrats', 0.083333333333333329),
#   (u'congratulations', 0.083333333333333329),
#   (u'well', 0.083333333333333329),
#   (u'flying', 0.083333333333333329),
#   (u'do', 0.083333333333333329)],
#  u'leaving anyone': [(u'have', 1.0)],
#  u'guesstimate on': [(u'hold', 1.0)],
#  u'ya too': [(u'will', 1.0)],
#  u'mxo42 henrikwagner73': [(u'jetbluerocks', 1.0)],
#  u'las fll': [(u'sju', 1.0)],
#  u'staff said': [(u'don', 1.0)],
#  u'prices after': [(u'you', 1.0)],
#  u'over destinationdragons': [(u'endtoken', 1.0)],
#  u'of change': [(u'fee', 0.33333333333333331),
#   (u'in', 0.33333333333333331),
#   (u'fees', 0.33333333333333331)],
#  u'players chgd': [(u'for', 1.0)],
#  u'class first': [(u'endtoken', 1.0)],
#  u'rude grouchy': [(u'agent', 1.0)],
#  u'yes last': [(u'month', 1.0)],
#  u'busted zippers': [(u'sorry', 1.0)],
#  u'team again': [(u'it', 0.5), (u'endtoken', 0.5)],
#  u'we am': [(u'what', 1.0)],
#  ...}

# %%
# Produce text with variety
def produce_text_sampling(gram_dict_probs, minlen=5, maxlen=20, tokens_so_far=None, verbose=False):
    if tokens_so_far is None:
        tokens_so_far = [u'starttoken']
    finished = False
    while not finished:
        for gram_dict_prob, n_gram_len in gram_dict_probs:
            if verbose:
                print("Tokens so far: {}, trying {} grams".format(tokens_so_far, n_gram_len))
            next_token = produce_next_token_sampling(tokens_so_far, gram_dict_prob, minlen=minlen, n_gram_len=n_gram_len)
            if next_token:
                if next_token == u'endtoken' and len(tokens_so_far) > minlen:
                    continue
                tokens_so_far.append(next_token)
                break
        # finish if endtoken generated
        if tokens_so_far[-1] == u'endtoken':
            finished = True
        # finish if tweet getting long
        if len(tokens_so_far) > maxlen:
            finished = True
        # finish if issue with next token
        if next_token is None:
            finished = True

    # clean text of start/end tokens
    text = u" ".join([t for t in tokens_so_far if t not in [u'starttoken', u'endtoken']])
    return text

# Randomly Sample Probability Distribution
def sample(options, probs):
    chosen = np.random.choice(options, p=probs)
    return chosen

# Produce the next token
def produce_next_token_sampling(tokens_so_far, preceding_gram_to_options_with_counts_normalized, minlen, n_gram_len):
    last_bigram = u" ".join(tokens_so_far[-1*(n_gram_len-1):])
    if n_gram_len == 1:
        last_bigram = u''
    options = preceding_gram_to_options_with_counts_normalized.get(last_bigram, None)
    if not options:
        return None
    option_tokens, probabilities = [o[0] for o in options], [o[1] for o in options]
    next_token = sample(option_tokens, probs=probabilities)
    return next_token

# %%
tokens_so_far = []
produce_text_sampling(gram_dict_probs, verbose=True)
# Out:
# Tokens so far: [u'starttoken'], trying 5 grams
# Tokens so far: [u'starttoken'], trying 4 grams
# Tokens so far: [u'starttoken'], trying 3 grams
# Tokens so far: [u'starttoken'], trying 2 grams
# Tokens so far: [u'starttoken', u'americanair'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair'], trying 4 grams
# Tokens so far: [u'starttoken', u'americanair'], trying 3 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh'], trying 4 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have', u'turned'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have', u'turned', u'itover'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have', u'turned', u'itover', u'to'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have', u'turned', u'itover', u'to', u'them'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have', u'turned', u'itover', u'to', u'them', u'but'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have', u'turned', u'itover', u'to', u'them', u'but', u'apparently'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have', u'turned', u'itover', u'to', u'them', u'but', u'apparently', u'losing'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have', u'turned', u'itover', u'to', u'them', u'but', u'apparently', u'losing', u'someones'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have', u'turned', u'itover', u'to', u'them', u'but', u'apparently', u'losing', u'someones', u'bag'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have', u'turned', u'itover', u'to', u'them', u'but', u'apparently', u'losing', u'someones', u'bag', u'on'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have', u'turned', u'itover', u'to', u'them', u'but', u'apparently', u'losing', u'someones', u'bag', u'on', u'their'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have', u'turned', u'itover', u'to', u'them', u'but', u'apparently', u'losing', u'someones', u'bag', u'on', u'their', u'honeymoon'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have', u'turned', u'itover', u'to', u'them', u'but', u'apparently', u'losing', u'someones', u'bag', u'on', u'their', u'honeymoon', u'doesn'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have', u'turned', u'itover', u'to', u'them', u'but', u'apparently', u'losing', u'someones', u'bag', u'on', u'their', u'honeymoon', u'doesn', u'require'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have', u'turned', u'itover', u'to', u'them', u'but', u'apparently', u'losing', u'someones', u'bag', u'on', u'their', u'honeymoon', u'doesn', u'require', u'accountability'], trying 5 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have', u'turned', u'itover', u'to', u'them', u'but', u'apparently', u'losing', u'someones', u'bag', u'on', u'their', u'honeymoon', u'doesn', u'require', u'accountability'], trying 4 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have', u'turned', u'itover', u'to', u'them', u'but', u'apparently', u'losing', u'someones', u'bag', u'on', u'their', u'honeymoon', u'doesn', u'require', u'accountability'], trying 3 grams
# Tokens so far: [u'starttoken', u'americanair', u'oh', u'already', u'have', u'turned', u'itover', u'to', u'them', u'but', u'apparently', u'losing', u'someones', u'bag', u'on', u'their', u'honeymoon', u'doesn', u'require', u'accountability'], trying 2 grams
# u'americanair oh already have turned itover to them but apparently losing someones bag on their honeymoon doesn require accountability hope'

# %%
produce_text_sampling(gram_dict_probs, tokens_so_far=[u'starttoken', u'united'], verbose=True)
# Out:
# Tokens so far: [u'starttoken', u'united'], trying 5 grams
# Tokens so far: [u'starttoken', u'united'], trying 4 grams
# Tokens so far: [u'starttoken', u'united'], trying 3 grams
# Tokens so far: [u'starttoken', u'united', u'after'], trying 5 grams
# Tokens so far: [u'starttoken', u'united', u'after'], trying 4 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting'], trying 5 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for'], trying 5 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over'], trying 5 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over', u'an'], trying 5 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over', u'an', u'hour'], trying 5 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over', u'an', u'hour', u'still'], trying 5 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over', u'an', u'hour', u'still', u'don'], trying 5 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over', u'an', u'hour', u'still', u'don', u'know'], trying 5 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over', u'an', u'hour', u'still', u'don', u'know', u'where'], trying 5 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over', u'an', u'hour', u'still', u'don', u'know', u'where', u'my'], trying 5 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over', u'an', u'hour', u'still', u'don', u'know', u'where', u'my', u'bags'], trying 5 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over', u'an', u'hour', u'still', u'don', u'know', u'where', u'my', u'bags', u'are'], trying 5 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over', u'an', u'hour', u'still', u'don', u'know', u'where', u'my', u'bags', u'are', u'is'], trying 5 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over', u'an', u'hour', u'still', u'don', u'know', u'where', u'my', u'bags', u'are', u'is', u'also'], trying 5 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over', u'an', u'hour', u'still', u'don', u'know', u'where', u'my', u'bags', u'are', u'is', u'also', u'equally'], trying 5 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over', u'an', u'hour', u'still', u'don', u'know', u'where', u'my', u'bags', u'are', u'is', u'also', u'equally', u'irritating'], trying 5 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over', u'an', u'hour', u'still', u'don', u'know', u'where', u'my', u'bags', u'are', u'is', u'also', u'equally', u'irritating', u'coltsmissingbags'], trying 5 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over', u'an', u'hour', u'still', u'don', u'know', u'where', u'my', u'bags', u'are', u'is', u'also', u'equally', u'irritating', u'coltsmissingbags'], trying 4 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over', u'an', u'hour', u'still', u'don', u'know', u'where', u'my', u'bags', u'are', u'is', u'also', u'equally', u'irritating', u'coltsmissingbags'], trying 3 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over', u'an', u'hour', u'still', u'don', u'know', u'where', u'my', u'bags', u'are', u'is', u'also', u'equally', u'irritating', u'coltsmissingbags'], trying 2 grams
# Tokens so far: [u'starttoken', u'united', u'after', u'waiting', u'for', u'over', u'an', u'hour', u'still', u'don', u'know', u'where', u'my', u'bags', u'are', u'is', u'also', u'equally', u'irritating', u'coltsmissingbags'], trying 1 grams
# u'united after waiting for over an hour still don know where my bags are is also equally irritating coltsmissingbags time'

# %%
for ti in range(50):
    print("Tweet", ti, produce_text_sampling(gram_dict_probs))
# Out:
# ('Tweet', 0, u'americanair usairways day has come where was suppose to get my money back but now prices are jacked up the')
# ('Tweet', 1, u'southwestair okay just signed up for trueblue and booked flight but keep getting an error message and only machine when')
# ('Tweet', 2, u'jetblue unhappy with hour delayed flight missed dinner tonight hr delay and now 20 min on tarmac worst experience ever')
# ('Tweet', 3, u'on the brink of bankruptcy jetblue our fleet on fleek http co 58b7swrpmq let see how things roll out in')
# ('Tweet', 4, u'united if your policy changed you must advise at the time of purchase same if you choose to vary it')
# ('Tweet', 5, u'united thanks for reminding me why switched to delta for coming in clutch and finally taking me home and despite')
# ('Tweet', 6, u'southwestair traveling with 13 year old thursday he does not need an id correct if so what time does gate')
# ('Tweet', 7, u'southwestair rocks open letter to flight attendant http co zfroinpszi lt my child was inspired thank you again ever even')
# ('Tweet', 8, u'usairways if you believe in keeping your customers happy especially after mistake was made on your part would be nice')
# ('Tweet', 9, u'jetblue why don you fly to nashville big thanks to the pilots on the 15 out of baltimore flying in')
# ('Tweet', 10, u'united your social listening capabilities are awful if this is the taste of the worlds largest airline heaven help aviation')
# ('Tweet', 11, u'americanair hi we have lost and found solution we want to offer for free to assist with contacting people when')
# ('Tweet', 12, u'southwestair no human contact for mths from americanair cust relations or refund dept if ever problem do have humans can')
# ('Tweet', 13, u'jetblue even tho the extra lbs are still going on the plane just as carry on where is the sense')
# ('Tweet', 14, u'southwestair think you have great people working for you as well as panam but will find other airlines in the')
# ('Tweet', 15, u'united just need to get to nyc its an hr wait now gate opened back we go good maybe we')
# ('Tweet', 16, u'americanair yes to the ios running ios it all works so much better now we ve been sitting in the')
# ('Tweet', 17, u'southwestair coming up on 10 hrs and all at the gate not leaving and without my baggage swa you are')
# ('Tweet', 18, u'americanair gah this is so frustrating nobody has my address here in the usa where are my bags so disorganised')
# ('Tweet', 19, u'united waiting on plane so long missed my connecting flight another night not being home thanks pathetic handled the stressful')
# ('Tweet', 20, u'americanair reebooked for tomorrow in aa 1389 lv dfw at 810 am arriving 12 50pm still open this flight so')
# ('Tweet', 21, u'southwestair weather where and at what time cancelled flighted no can because meeting was today which is now cancelled flightled')
# ('Tweet', 22, u'united are you aware your airbus fleet sucks rather fly 130 full of rubber dog shit sunday nocareforcustomers away the')
# ('Tweet', 23, u'united need to speak with customer service at the airport tomorrow morning and see what my options are need flight')
# ('Tweet', 24, u'southwestair southwest mobile boarding passes now available in ios passbook http co xmrvr4lgeg http co wjoc9f14su tori_leggieri still haven talked')
# ('Tweet', 25, u'usairways ve been on hold for hours and call was dropped help need flight out tonight isn there anything else')
# ('Tweet', 26, u'usairways thanks for the info have good day to fly two delayed flights still on plane at ewr waiting over')
# ('Tweet', 27, u'americanair yes and the auto rebook confirmed an outbound that departs after the return flight fire the software programmers parked')
# ('Tweet', 28, u'usairways sorry didn realize wasn following you now standing in line waiting for reflight booking problems options good luck with')
# ('Tweet', 29, u'jetblue ceo battles to appease passengers and wall street waterbury republican american http co d1ergpdwsj no info to upgrade using')
# ('Tweet', 30, u'southwestair finally integration passbook is great valentine gift better then chocolate flight you do heart me feel guilty because it')
# ('Tweet', 31, u'americanair sat on the runway for more hrs b4 takeoff 10 hrs late flight 30 am pilot plainly stated it')
# ('Tweet', 32, u'united that is not in line with your responses here and now waiting until tomorrow morning because all the flights')
# ('Tweet', 33, u'united boarding time shows 35 min and your gate agent started at 45 showed up at 00 and they had')
# ('Tweet', 34, u'americanair while aggravated shouldn baggage fees disappear now that gas prices have dropped ball late flightly currently lost luggage want')
# ('Tweet', 35, u'southwestair on hold for 45 mins help reason alone with two kids at least put her in group in prev')
# ('Tweet', 36, u'united dm sent thanks so much for the strong customer service ever how can you let people be assaulted on')
# ('Tweet', 37, u'jetblue thanks so much can wait to fly with you guys again if my instrument is involved 10 10 30')
# ('Tweet', 38, u'united private jet would have been cool do does not work ll try again with swa on friday the luv')
# ('Tweet', 39, u'united ridiculous have to be refunded whenever get at my final destination or not that why am very concerned that')
# ('Tweet', 40, u'southwestair how do get companion pass thanks lin nice just saying sorry thankfully submitting complaint got resolution from an amazing')
# ('Tweet', 41, u'jetblue no it weird picked other cities just to test those worked not the one want works on phone though')
# ('Tweet', 42, u'americanair my navy sisters flight 2470 cancld she can get an agent they ve called her back to be put')
# ('Tweet', 43, u'united is it customary to upgrade flight attendant in uniform vs passengers one is in 1b on flt 1020 now')
# ('Tweet', 44, u'united nope no case id either time home has our plane left or not it is your fault shouldn there')
# ('Tweet', 45, u'usairways your staff at lax really messed up on this one failing to scan my suitcase tag to charge 750')
# ('Tweet', 46, u'united booked 11 tix month ago and now its about 157 cheaper and customer service was useless what up with')
# ('Tweet', 47, u'jetblue our fleet on fleek http co a7nvbj8ipx ve been used in the first place to stay day longer have')
# ('Tweet', 48, u'southwestair been waiting for 70 minutes on hold because yall cancelled flightled my return flight answer the phone now or')
# ('Tweet', 49, u'united my friend lost luggage on flight 1547 what to do anything about it lied to me about supervisors amp')
